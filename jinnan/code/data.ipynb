# %%
import os
from IPython.core.display import Image, display


import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams["figure.figsize"] = (12, 8)

# %matplotlib inline

# %%
data_root = '../data/First_round_data'
train_root = os.path.join(data_root, 'jinnan2_round1_train_20190305')

# %%
![title]("../data/First_round_data/jinnan2_round1_train_20190305/normal/190102_205218_00148996.jpg")
# Out:
# /bin/sh: 1: Syntax error: word unexpected (expecting ")")

# %%
display(Image('../data/First_round_data/jinnan2_round1_train_20190305/normal/190102_205218_00148996.jpg', width=100, height=100, unconfined=True))
