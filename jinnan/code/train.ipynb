# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
import import_ipynb
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

import torch.utils.data as data
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

# %%
from datasets.jinnan import JinnanDetection
# Out:
# importing Jupyter notebook from /dev/sdb1/code/python/jinnan/code/datasets/jinnan.ipynb

# %%
def collate(batch):
    data = [item[0] for item in batch]
    target = [item[1] for item in batch]
    return [data, target]

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

transform = transforms.Compose([
    transforms.Scale(256),
    transforms.RandomCrop(224),
    transforms.ToTensor()
])

# %%
batch_size = 4
dataset = JinnanDetection('../data/First_round_data/jinnan2_round1_train_20190305', 'train_no_poly.json', transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=1) #, collate_fn=collate)
# Out:
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!

# %%
fig = plt.figure()

for i, (imgs, labels) in enumerate(dataloader):
    print(imgs.shape)
#     print(imgs)
    print(labels)
    
    ax = fig.add_subplot(1, 1, i+1)
    ax.imshow(imgs[0].numpy().transpose([1,2,0]))
    
    break
# Out:
# torch.Size([4, 3, 224, 224])
# [{'area': [], 'id': tensor([1584,  755, 1233, 5308]), 'minAreaRect': [[tensor([215, 525, 368, 153]), tensor([148, 317, 281,  88])], [tensor([210, 519, 342, 147]), tensor([142, 310, 183,  48])], [tensor([238, 543, 397, 339]), tensor([114, 283, 169,  19])], [tensor([244, 550, 423, 345]), tensor([120, 289, 267,  59])]], 'category_id': tensor([4, 4, 1, 5]), 'iscrowd': tensor([0, 0, 0, 0]), 'segmentation': [], 'bbox': [tensor([211, 520, 344, 150]), tensor([118, 287, 178,  46]), tensor([ 33,  31,  78, 194]), tensor([28, 29, 96, 40])], 'image_id': tensor([337, 171, 269, 979])}, {'area': [], 'id': tensor([1585,  756, 1234, 5309]), 'minAreaRect': [[tensor([224, 543, 436, 266]), tensor([148, 326, 252, 191])], [tensor([222, 536, 428, 204]), tensor([141, 319, 205, 110])], [tensor([267, 561, 470, 250]), tensor([131, 293, 198,  76])], [tensor([268, 569, 479, 311]), tensor([139, 301, 244, 156])]], 'category_id': tensor([4, 4, 1, 5]), 'iscrowd': tensor([0, 0, 0, 0]), 'segmentation': [], 'bbox': [tensor([225, 537, 429, 245]), tensor([132, 296, 203,  76]), tensor([44, 31, 50, 58]), tensor([ 16,  29,  45, 102])], 'image_id': tensor([337, 171, 269, 979])}]

# %%
fig = plt.figure()

# %%
fig.add_subplot?
