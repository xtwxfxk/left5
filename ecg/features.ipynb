# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import featexp

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = (12, 8)

# %matplotlib inline

# %%
data_root = '/home/left/code/python/left5/xd/ecg_pytorch/data'
train_root = os.path.join(data_root, 'hf_round1_train/train')

train_label_path = os.path.join(data_root, 'hf_round1_label.txt')

# %%
arrythmia = pd.read_csv(os.path.join(data_root, 'hf_round1_arrythmia.txt'), header=None)

# %%
f2 = os.path.join(train_root, '2.txt')

# %%
df = pd.read_csv(f2, sep=' ')

# %%
train_label = pd.read_csv(train_label_path, sep='\t', names=list(range(12)))

# %%
train_label
# Out:
#               0     1       2       3            4       5    6    7    8   \
# 0          2.txt   NaN     NaN    窦性心律       QRS低电压     NaN  NaN  NaN  NaN
# 1          5.txt  40.0  FEMALE    窦性心律       QRS低电压     NaN  NaN  NaN  NaN
# 2          9.txt  54.0  FEMALE  窦性心动过缓       QRS低电压     NaN  NaN  NaN  NaN
# 3         12.txt  25.0  FEMALE    窦性心律       QRS低电压     NaN  NaN  NaN  NaN
# 4         14.txt  37.0  FEMALE    窦性心律       QRS低电压     NaN  NaN  NaN  NaN
# ...          ...   ...     ...     ...          ...     ...  ...  ...  ...
# 24101  44301.txt  69.0  FEMALE    窦性心律  不完全性右束支传导阻滞  左心室高电压  NaN  NaN  NaN
# 24102  44302.txt  48.0    MALE    窦性心律       左心室高电压     NaN  NaN  NaN  NaN
# 24103  44303.txt  59.0    MALE    窦性心律  不完全性右束支传导阻滞  左心室高电压  NaN  NaN  NaN
# 24104  44304.txt  58.0    MALE    窦性心律       左心室高电压    T波改变  NaN  NaN  NaN
# 24105  44305.txt  69.0    MALE  窦性心动过缓       左心室高电压     NaN  NaN  NaN  NaN
#
#         9    10  11
# 0      NaN  NaN NaN
# 1      NaN  NaN NaN
# ...

# %%
arrythmia
# Out:
#                0
# 0           窦性心律
# 1           T波改变
# 2         窦性心动过缓
# 3          ST段改变
# 4          正常ECG
# 5         左心室高电压
# 6         ST-T改变
# 7         窦性心动过速
# 8          临界ECG
# 9         QRS低电压
# 10          房性早搏
# 11          电轴左偏
# 12          电轴右偏
# 13          心房颤动
# 14         异常ECG
# 15          室性早搏
# 16    完全性右束支传导阻滞
# 17        窦性心律不齐
# 18         左心室肥大
# 19       右束支传导阻滞
# 20      一度房室传导阻滞
# 21          快心室率
# 22   不完全性右束支传导阻滞
# 23      非特异性T波异常
# 24        QT间期延长
# 25      左前分支传导阻滞
# 26     非特异性ST段异常
# 27         差异性传导
# 28  非特异性ST段与T波异常
# 29          起搏心律
# 30         短PR间期
# 31        下壁异常Q波
# 32       快室率心房颤动
# 33         逆钟向转位
# 34       室内差异性传导
# 35         早期复极化
# 36           二联律
# 37         室上性早搏
# 38         顺钟向转位
# 39         复极化异常
# 40      未下传的房性早搏
# 41          肺心病型
# 42          慢心室率
# 43      短串房性心动过速
# 44    非特异性室内传导延迟
# 45         右心房扩大
# 46       左束支传导阻滞
# 47     前间壁R波递增不良
# 48         右心室肥大
# 49        房室传导延缓
# 50       双分支传导阻滞
# ...
