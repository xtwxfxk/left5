# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# da = pd.read_csv('data/Chapter 7/d-ibmln98wm.txt', sep='\s+')
da = np.loadtxt('data/Chapter 7/d-ibmln98wm.txt')

# %%
da[:, 1]
# Out:
# array([ 0.00384, -0.00472, -0.01483, ..., -0.01173, -0.00245, -0.01324])

# %%
plt.figure(figsize=(16, 4))
plt.plot(da[:, 1])

# %%
x = np.linspace(-2, 2, 1000)
y1 = np.exp(x)
y2 = np.log(x)

plt.figure(figsize=(12, 4))
plt.plot(x, y1, label='exp')
plt.plot(x, y2, label='log')
plt.legend() #handles=[y_exp, y_log])
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
