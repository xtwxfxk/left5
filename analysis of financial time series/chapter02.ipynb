# %%
import numpy as np
import scipy as cp
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ### Page 30

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.ar_model import AR
# Out:
# /usr/local/lib/python2.7/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
da = pd.read_csv('data/Chapter 2/m-ibm3dx2608.txt', sep='\s+')

# %%
sibm = da['ibmrtn']

# %%
acorr_ljungbox(sibm, lags=5)
# Out:
# (array([ 1.59186057,  1.63285984,  1.95680258,  2.935275  ,  3.36822158]),
#  array([ 0.20706051,  0.44200684,  0.58142072,  0.56871475,  0.64341427]))

# %%
libm = np.log(sibm + 1)

# %%
acorr_ljungbox(libm, lags=5)
# Out:
# (array([ 1.96700707,  1.96751272,  2.16162956,  2.95889339,  3.52357851]),
#  array([ 0.1607659 ,  0.37390394,  0.53954564,  0.56472789,  0.61982294]))

# %% [markdown]
# ### Page 38

# %%
gnp = np.loadtxt('data/Chapter 2/dgnp82.txt')

# %%
gnp.shape
# Out:
# (176,)

# %%
plt.figure(figsize=(16, 4))
plt.plot(gnp, 'o-')

# %%
pi = pd.period_range('1947-02', periods=176, freq='3M')

# %%
plt.figure(figsize=(16, 4))
xind = np.arange(0, gnp.shape[0], 25)
plt.xticks(xind, pi[xind])
plt.plot(gnp, 'o-')

# %% [markdown]
# ### Page 42

# %%
gnp = np.loadtxt('data/Chapter 4/q-gnp4791.txt')

# %%
gnp.shape
# Out:
# (176,)

# %%
ar = AR(gnp)

# %%
ar.fit([27.847])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-d70dda26d0a9> in <module>()
# ----> 1 ar.fit([27.847])
#
# /usr/local/lib/python2.7/site-packages/statsmodels/tsa/ar_model.pyc in fit(self, maxlag, method, ic, trend, transparams, start_params, solver, maxiter, full_output, disp, callback, **kwargs)
#     549         # redo estimation for best lag
#     550         # make LHS
# --> 551         Y = endog[k_ar:, :]
#     552         # make lagged RHS
#     553         X = self._stackX(k_ar, trend)  # sets self.k_trend
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# #

# %%
da = pd.read_csv('data/Chapter 2/m-deciles08.txt', sep='\s+')

# %%
d1 = da['CAP1RET']

# %%
# da = pd.read_csv('data/Chapter 2/w-gs1n36299.txt', sep='\s+')

da = np.loadtxt('data/Chapter 2/w-gs1n36299.txt')

# %%
t1 = da[:, 0]
t3 = da[:, 1]

d1 = np.diff(t1)
d3 = np.diff(t3)

# %%
# plt.plot(t1, t3, '.')
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121)
ax1.plot(t1, t3, '.')

ax2 = fig.add_subplot(122)
ax2.plot(d1, d3, '.')
plt.show()
