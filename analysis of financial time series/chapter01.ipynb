# %%
import numpy as np
import scipy as cp
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf

# %%
# %matplotlib inline

# %%
da = pd.read_csv('data/Chapter 1/m-gm3dx7508.txt', sep='\s+')

# %%
gm = da['gm']

# %%
plt.figure(figsize=(16, 4))
plt.plot(gm)

# %%
acf_gm = acf(gm, nlags=24)
# Out:
# d:\soft\python\python37\lib\site-packages\statsmodels\tsa\stattools.py:671: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning,

# %%
plt.figure(figsize=(16, 4))
ind = np.arange(acf_gm.shape[0])
plt.bar(ind, acf_gm, width=0.1)
# Out:
# <BarContainer object of 25 artists>

# %%
acf?

# %%
gm.autocorr()
# Out:
# 0.053451160994418385

# %%
np.corrcoef(gm)
# Out:
# 1.0
