# %% [markdown]
# ### Stock Trading Strategy using Classification Algorithms to Predict Market Movements and Backtesting

# %%
# make the necessary imports 
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import yfinance as yf
import warnings
from sklearn import linear_model
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
import datetime
import pyfolio as pf
import backtrader as bt
from backtrader.feeds import PandasData
import warnings

# set the style and ignore warnings
plt.style.use('seaborn-colorblind')
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
# Out:
# d:\code\python\pyfolio\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %%
# this is to display images in notebook
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Data Gathering

# %%
# ticker and the start and end dates for testing
# ticker = '^NSEI' # Nifty 50 benchmark
# start = datetime.datetime(2010, 1, 1)
# end = datetime.datetime(2020, 7, 31)

start = '2021-01-01'
end = '2021-12-12'

# %%
# download ticker ‘Adj Close’ price from yahoo finance
# stock =  yf.download(ticker, progress=True, actions=True,start=start, end=end)['Adj Close']
# stock = pd.DataFrame(stock)
# stock.rename(columns = {'Adj Close':ticker}, inplace=True)
# stock.head(2)

# %%
from lutils.stock import LTdxHq

# %%
ltdxhq = LTdxHq()

# %%
code = '600519' # 000032 300142 603636 600519
ticker = code

df = ltdxhq.get_k_data_daily(code, start=start, end=end)
df.index = pd.to_datetime(df.index)

prices = df
stock = pd.DataFrame(df.close)

stock.rename(columns = {'close': ticker}, inplace=True)
stock.head(2)
# Out:
#              600519
# date
# 2021-01-04  1978.37
# 2021-01-05  2040.24

# %%
# calculate daily log returns and market direction
stock['returns'] = np.log(stock / stock.shift(1))
stock.dropna(inplace=True)
stock['direction'] = np.sign(stock['returns']).astype(int)
stock.head(3)
# Out:
#              600519   returns  direction
# date
# 2021-01-05  2040.24  0.030794          1
# 2021-01-06  2080.41  0.019498          1
# 2021-01-07  2120.04  0.018870          1

# %%
# visualize the closing price and daily returns
fig, ax = plt.subplots(2, 1, sharex=True, figsize = (12,6))
ax[0].plot(stock[ticker], label = f'{ticker} Adj Close')
ax[0].set(title = f'{ticker} Closing Price', ylabel = 'Price')
ax[0].grid(True)
ax[0].legend()

ax[1].plot(stock['returns'], label = 'Daily Returns')
ax[1].set(title = f'{ticker} Daily Retunrs', ylabel = 'Returns')
ax[1].grid(True)
plt.legend()

plt.tight_layout();
# plt.savefig('images/chart1', dpi=300)
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
# define the number of lags
lags = [1, 2, 3, 4, 5]

# %%
# compute lagged log returns
cols = []
for lag in lags:
    col = f'rtn_lag{lag}'
    stock[col] = stock['returns'].shift(lag)
    cols.append(col)

stock.dropna(inplace=True)
stock.head(2)
# Out:
#              600519   returns  direction  rtn_lag1  rtn_lag2  rtn_lag3  \
# date
# 2021-01-12  2140.74  0.028716          1  0.004645 -0.023645  0.018870
# 2021-01-13  2143.81  0.001433          1  0.028716  0.004645 -0.023645
#
#             rtn_lag4  rtn_lag5
# date
# 2021-01-12  0.019498  0.030794
# 2021-01-13  0.018870  0.019498

# %%
# cols

# %%
# function to transform the lag returns to binary values (0,+1)
def create_bins(data, bins=[0]):
    global cols_bin
    cols_bin = []
    for col in cols:
        col_bin = col + '_bin'
        data[col_bin] = np.digitize(data[col], bins=bins)  
        cols_bin.append(col_bin)

# %%
create_bins(stock)
stock[cols+cols_bin].head(2)
# Out:
#             rtn_lag1  rtn_lag2  rtn_lag3  rtn_lag4  rtn_lag5  rtn_lag1_bin  \
# date
# 2021-01-12  0.004645 -0.023645  0.018870  0.019498  0.030794             1
# 2021-01-13  0.028716  0.004645 -0.023645  0.018870  0.019498             1
#
#             rtn_lag2_bin  rtn_lag3_bin  rtn_lag4_bin  rtn_lag5_bin
# date
# 2021-01-12             0             1             1             1
# 2021-01-13             1             0             1             1

# %%
# cols_bin

# %% [markdown]
# ### Build and Apply Classification Machine Learning Algorithms

# %% [markdown]
# Select Logistic regression, Gaussian Naive Bayes, Support Vector Machine, Random Forest, and MLP Classifier approaches to predict the market direction. Please refer sklearn documentation for detail on these and other algorithms.
# https://scikit-learn.org/stable/index.html

# %%
# create a dictionary of selected algorithms
models = {
    'log_reg': linear_model.LogisticRegression(),
    'gauss_nb': GaussianNB(),
    'svm': SVC(),
    'random_forest': RandomForestClassifier(max_depth=15, n_estimators=200),
    'MLP' : MLPClassifier(max_iter=500),
}

# %%
# function that fits all models.
def fit_models(data):  
    mfit = {model: models[model].fit(data[cols_bin], data['direction']) for model in models.keys()}

# %%
# function that predicts (derives all position values) from the fitted models
def derive_positions(data):  
    for model in models.keys():
        data['pos_' + model] = models[model].predict(data[cols_bin])

# %%
# function to evaluate all trading strategies
def evaluate_strats(data):  
    global strategy_rtn
    strategy_rtn = []
    for model in models.keys():
        col = 'strategy_' + model 
        data[col] = data['pos_' + model] * data['returns']
        strategy_rtn.append(col)
    strategy_rtn.insert(0, 'returns')

# %%
# fit the models
fit_models(stock)

# %%
# derives all position values
derive_positions(stock)

# %%
# evaluate all trading strategies by multiplying predicted directions to actual daily returns
evaluate_strats(stock)

# %%
# calculate total return and std. deviation of each strategy
print('\nTotal Returns:')
print(stock[strategy_rtn].sum().apply(np.exp))
print('\nAnnual Volatility:')
stock[strategy_rtn].std() * 252 ** 0.5
# Out:
# Total Returns:
# returns                   0.885037
# strategy_log_reg          1.629947
# strategy_gauss_nb         1.566230
# strategy_svm              2.652746
# strategy_random_forest    2.631033
# strategy_MLP              2.671210
# dtype: float64
#
# Annual Volatility:
# returns                   0.394869
# strategy_log_reg          0.392766
# strategy_gauss_nb         0.393118
# strategy_svm              0.385987
# strategy_random_forest    0.386140
# strategy_MLP              0.385856
# dtype: float64

# %%
# number of trades over time for highest and second highest return strategy
print('Number of trades SVM = ', (stock['pos_svm'].diff()!=0).sum())
print('Number of trades Ramdom Forest = ',(stock['pos_random_forest'].diff()!=0).sum())
# Out:
# Number of trades SVM =  95
# Number of trades Ramdom Forest =  91

# %%
# stock[[ticker]+ strategy_rtn].head(2)

# %%
# vectorized backtesting of the resulting trading strategies and visualize the performance over time
ax = stock[strategy_rtn].cumsum().apply(np.exp).plot(figsize=(12, 6), 
                                                     title = 'Machine Learning Classifiers Return Comparison')
ax.set_ylabel("Cumulative Returns")
ax.grid(True);
plt.tight_layout();
# plt.savefig('images/chart2', dpi=300)
plt.show()

# %% [markdown]
# ### Backtesting of Selected Strategy using Backtrader

# %%
# fetch the daily pricing data from yahoo finance
# prices =  yf.download(ticker, progress=True, actions=True, start=start, end=end)
# prices.head(2)

# %%
# rename the columns as needed for Backtrader
# prices.drop(['Close','Dividends','Stock Splits'], inplace=True, axis=1)
# prices.rename(columns = {'Open':'open','High':'high','Low':'low','Adj Close':'close','Volume':'volume',
#                          }, inplace=True)

# %%
prices.head(3)
# Out:
#                open    close     high      low     volume        amount
# date
# 2021-01-04  1981.32  1978.37  1986.29  1965.30  4351400.0  8.686921e+09
# 2021-01-05  1971.44  2040.24  2040.24  1963.97  5211605.0  1.059256e+10
# 2021-01-06  2045.54  2080.41  2105.18  2017.04  4741020.0  9.882594e+09

# %%
# add the predicted column to prices dataframe. This will be used as signal for buy or sell
predictions = stock['strategy_svm']
predictions = pd.DataFrame(predictions)
predictions.rename(columns = {'strategy_svm':'predicted'}, inplace=True)
prices = predictions.join(prices, how='right').dropna()
prices.head(2)
# Out:
#             predicted     open    close     high      low     volume  \
# date
# 2021-01-12   0.028716  2068.52  2140.74  2140.74  2065.55  4105859.0
# 2021-01-13   0.001433  2143.81  2143.81  2153.05  2115.08  3438993.0
#
#                   amount
# date
# 2021-01-12  8.800558e+09
# 2021-01-13  7.418331e+09

# %%
# prices[['predicted']].sum().apply(np.exp)

# %%
OHLCV = ['open', 'high', 'low', 'close', 'volume']

# %%
# class to define the columns we will provide
class SignalData(PandasData):
    """
    Define pandas DataFrame structure
    """
    cols = OHLCV + ['predicted']

    # create lines
    lines = tuple(cols)

    # define parameters
    params = {c: -1 for c in cols}
    params.update({'datetime': None})
    params = tuple(params.items())

# %% [markdown]
# Strategy:
# 1.	Buy when the predicted value is +1 and sell (only if stock is in possession) when the predicted value is -1.
# 2.	All-in strategy—when creating a buy order, buy as many shares as possible.
# 3.	Short selling is not allowed

# %%
# define backtesting strategy class
class MLStrategy(bt.Strategy):
    params = dict(
    )
    
    def __init__(self):
        # keep track of open, close prices and predicted value in the series
        self.data_predicted = self.datas[0].predicted
        self.data_open = self.datas[0].open
        self.data_close = self.datas[0].close
        
        # keep track of pending orders/buy price/buy commission
        self.order = None
        self.price = None
        self.comm = None

    # logging function
    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return

        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f},Commission: {order.executed.comm:.2f}'
                )
                self.price = order.executed.price
                self.comm = order.executed.comm
            else:
                self.log(f'SELL EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f},Commission: {order.executed.comm:.2f}'
                )

        # report failed order
        elif order.status in [order.Canceled, order.Margin, 
                              order.Rejected]:
            self.log('Order Failed')

        # set no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'OPERATION RESULT --- Gross: {trade.pnl:.2f}, Net: {trade.pnlcomm:.2f}')

    # We have set cheat_on_open = True.This means that we calculated the signals on day t's close price, 
    # but calculated the number of shares we wanted to buy based on day t+1's open price.
    def next_open(self):
        if not self.position:
            if self.data_predicted > 0:
                # calculate the max number of shares ('all-in')
                size = int(self.broker.getcash() / self.datas[0].open)
                # buy order
                self.log(f'BUY CREATED --- Size: {size}, Cash: {self.broker.getcash():.2f}, Open: {self.data_open[0]}, Close: {self.data_close[0]}')
                self.buy(size=size)
        else:
            if self.data_predicted < 0:
                # sell order
                self.log(f'SELL CREATED --- Size: {self.position.size}')
                self.sell(size=self.position.size)

# %%
# instantiate SignalData class
data = SignalData(dataname=prices)

# %%
# instantiate Cerebro, add strategy, data, initial cash, commission and pyfolio for performance analysis
cerebro = bt.Cerebro(stdstats = False, cheat_on_open=True)
cerebro.addstrategy(MLStrategy)
cerebro.adddata(data, name=ticker)
cerebro.broker.setcash(100000.0)
cerebro.broker.setcommission(commission=0.001)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

# %%
# run the backtest
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
backtest_result = cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2021-01-13, BUY CREATED --- Size: 46, Cash: 100000.00, Open: 2143.81, Close: 2143.81
# 2021-01-13, BUY EXECUTED --- Price: 2143.81, Cost: 98615.26,Commission: 98.62
# 2021-01-18, SELL CREATED --- Size: 46
# 2021-01-18, SELL EXECUTED --- Price: 2041.83, Cost: 98615.26,Commission: 93.92
# 2021-01-18, OPERATION RESULT --- Gross: -4691.08, Net: -4883.62
# 2021-01-19, BUY CREATED --- Size: 46, Cash: 95116.38, Open: 2053.77, Close: 1990.66
# 2021-01-19, BUY EXECUTED --- Price: 2053.77, Cost: 94473.42,Commission: 94.47
# 2021-01-20, SELL CREATED --- Size: 46
# 2021-01-20, SELL EXECUTED --- Price: 1989.27, Cost: 94473.42,Commission: 91.51
# 2021-01-20, OPERATION RESULT --- Gross: -2967.00, Net: -3152.98
# 2021-01-21, BUY CREATED --- Size: 45, Cash: 91963.40, Open: 2028.89, Close: 2050.69
# 2021-01-21, BUY EXECUTED --- Price: 2028.89, Cost: 91300.05,Commission: 91.30
# 2021-01-25, SELL CREATED --- Size: 45
# 2021-01-25, SELL EXECUTED --- Price: 2063.57, Cost: 91300.05,Commission: 92.86
# 2021-01-25, OPERATION RESULT --- Gross: 1560.60, Net: 1376.44
# 2021-01-26, BUY CREATED --- Size: 43, Cash: 93339.84, Open: 2164.62, Close: 2121.91
# 2021-01-26, BUY EXECUTED --- Price: 2164.62, Cost: 93078.66,Commission: 93.08
# 2021-01-28, SELL CREATED --- Size: 43
# 2021-01-28, SELL EXECUTED --- Price: 2060.60, Cost: 93078.66,Commission: 88.61
# 2021-01-28, OPERATION RESULT --- Gross: -4472.86, Net: -4654.54
# 2021-02-01, BUY CREATED --- Size: 42, Cash: 88685.30, Open: 2110.13, Close: 2089.64
# 2021-02-01, Order Failed
# 2021-02-02, BUY CREATED --- Size: 42, Cash: 88685.30, Open: 2092.51, Close: 2124.99
# 2021-02-02, BUY EXECUTED --- Price: 2092.51, Cost: 87885.42,Commission: 87.89
# 2021-02-08, SELL CREATED --- Size: 42
# 2021-02-08, SELL EXECUTED --- Price: 2315.20, Cost: 87885.42,Commission: 97.24
# 2021-02-08, OPERATION RESULT --- Gross: 9352.98, Net: 9167.86
# 2021-02-09, BUY CREATED --- Size: 41, Cash: 97853.15, Open: 2346.7, Close: 2433.51
# 2021-02-09, BUY EXECUTED --- Price: 2346.70, Cost: 96214.70,Commission: 96.21
# 2021-02-22, SELL CREATED --- Size: 41
# 2021-02-22, SELL EXECUTED --- Price: 2432.10, Cost: 96214.70,Commission: 99.72
# 2021-02-22, OPERATION RESULT --- Gross: 3501.40, Net: 3305.47
# 2021-02-24, BUY CREATED --- Size: 44, Cash: 101158.62, Open: 2286.46, Close: 2168.58
# 2021-02-24, BUY EXECUTED --- Price: 2286.46, Cost: 100604.24,Commission: 100.60
# 2021-02-25, SELL CREATED --- Size: 44
# 2021-02-25, SELL EXECUTED --- Price: 2188.39, Cost: 100604.24,Commission: 96.29
# 2021-02-25, OPERATION RESULT --- Gross: -4315.08, Net: -4511.97
# 2021-03-02, BUY CREATED --- Size: 44, Cash: 96646.65, Open: 2159.66, Close: 2038.8
# 2021-03-02, BUY EXECUTED --- Price: 2159.66, Cost: 95025.04,Commission: 95.03
# 2021-03-04, SELL CREATED --- Size: 44
# 2021-03-04, SELL EXECUTED --- Price: 2075.46, Cost: 95025.04,Commission: 91.32
# 2021-03-04, OPERATION RESULT --- Gross: -3704.80, Net: -3891.15
# 2021-03-09, BUY CREATED --- Size: 47, Cash: 92755.50, Open: 1936.76, Close: 1918.92
# 2021-03-09, BUY EXECUTED --- Price: 1936.76, Cost: 91027.72,Commission: 91.03
# 2021-03-11, SELL CREATED --- Size: 47
# 2021-03-11, SELL EXECUTED --- Price: 1956.58, Cost: 91027.72,Commission: 91.96
# 2021-03-11, OPERATION RESULT --- Gross: 931.54, Net: 748.55
# 2021-03-12, BUY CREATED --- Size: 45, Cash: 93504.06, Open: 2050.69, Close: 2007.1
# 2021-03-12, BUY EXECUTED --- Price: 2050.69, Cost: 92281.05,Commission: 92.28
# 2021-03-17, SELL CREATED --- Size: 45
# 2021-03-17, SELL EXECUTED --- Price: 1981.34, Cost: 92281.05,Commission: 89.16
# 2021-03-17, OPERATION RESULT --- Gross: -3120.75, Net: -3302.19
# 2021-03-19, BUY CREATED --- Size: 44, Cash: 90201.86, Open: 2016.02, Close: 1991.25
# 2021-03-19, BUY EXECUTED --- Price: 2016.02, Cost: 88704.88,Commission: 88.70
# 2021-03-29, SELL CREATED --- Size: 44
# 2021-03-29, SELL EXECUTED --- Price: 2024.14, Cost: 88704.88,Commission: 89.06
# 2021-03-29, OPERATION RESULT --- Gross: 357.28, Net: 179.51
# 2021-03-31, BUY CREATED --- Size: 44, Cash: 90381.38, Open: 2026.02, Close: 1990.26
# 2021-03-31, BUY EXECUTED --- Price: 2026.02, Cost: 89144.88,Commission: 89.14
# 2021-04-01, SELL CREATED --- Size: 44
# 2021-04-01, SELL EXECUTED --- Price: 2002.15, Cost: 89144.88,Commission: 88.09
# 2021-04-01, OPERATION RESULT --- Gross: -1050.28, Net: -1227.52
# 2021-04-02, BUY CREATED --- Size: 43, Cash: 89153.86, Open: 2036.82, Close: 2141.83
# 2021-04-02, BUY EXECUTED --- Price: 2036.82, Cost: 87583.26,Commission: 87.58
# 2021-04-06, SELL CREATED --- Size: 43
# 2021-04-06, SELL EXECUTED --- Price: 2140.84, Cost: 87583.26,Commission: 92.06
# 2021-04-06, OPERATION RESULT --- Gross: 4472.86, Net: 4293.22
# 2021-04-07, BUY CREATED --- Size: 44, Cash: 93447.08, Open: 2084.43, Close: 2041.77
# 2021-04-07, BUY EXECUTED --- Price: 2084.43, Cost: 91714.92,Commission: 91.71
# 2021-04-14, SELL CREATED --- Size: 44
# 2021-04-14, SELL EXECUTED --- Price: 2016.02, Cost: 91714.92,Commission: 88.70
# 2021-04-14, OPERATION RESULT --- Gross: -3010.04, Net: -3190.46
# 2021-04-15, BUY CREATED --- Size: 44, Cash: 90256.62, Open: 2011.95, Close: 1996.8
# 2021-04-15, BUY EXECUTED --- Price: 2011.95, Cost: 88525.80,Commission: 88.53
# 2021-04-16, SELL CREATED --- Size: 44
# 2021-04-16, SELL EXECUTED --- Price: 2006.19, Cost: 88525.80,Commission: 88.27
# 2021-04-16, OPERATION RESULT --- Gross: -253.44, Net: -430.24
# 2021-04-19, BUY CREATED --- Size: 44, Cash: 89826.38, Open: 2035.83, Close: 2068.52
# 2021-04-19, BUY EXECUTED --- Price: 2035.83, Cost: 89576.52,Commission: 89.58
# 2021-04-27, SELL CREATED --- Size: 44
# 2021-04-27, SELL EXECUTED --- Price: 2067.61, Cost: 89576.52,Commission: 90.97
# 2021-04-27, OPERATION RESULT --- Gross: 1398.32, Net: 1217.77
# 2021-04-29, BUY CREATED --- Size: 44, Cash: 91044.15, Open: 2027.94, Close: 2007.46
# 2021-04-29, BUY EXECUTED --- Price: 2027.94, Cost: 89229.36,Commission: 89.23
# 2021-04-30, SELL CREATED --- Size: 44
# 2021-04-30, SELL EXECUTED --- Price: 2007.10, Cost: 89229.36,Commission: 88.31
# 2021-04-30, OPERATION RESULT --- Gross: -916.96, Net: -1094.50
# 2021-05-06, BUY CREATED --- Size: 45, Cash: 89949.65, Open: 1981.34, Close: 1940.72
# 2021-05-06, BUY EXECUTED --- Price: 1981.34, Cost: 89160.30,Commission: 89.16
# 2021-05-10, SELL CREATED --- Size: 45
# 2021-05-10, SELL EXECUTED --- Price: 1882.27, Cost: 89160.30,Commission: 84.70
# 2021-05-10, OPERATION RESULT --- Gross: -4458.15, Net: -4632.01
# 2021-05-11, BUY CREATED --- Size: 45, Cash: 85317.63, Open: 1858.5, Close: 1940.72
# 2021-05-11, BUY EXECUTED --- Price: 1858.50, Cost: 83632.50,Commission: 83.63
# 2021-05-13, SELL CREATED --- Size: 45
# 2021-05-13, SELL EXECUTED --- Price: 1947.41, Cost: 83632.50,Commission: 87.63
# 2021-05-13, OPERATION RESULT --- Gross: 4000.95, Net: 3829.68
# 2021-05-17, BUY CREATED --- Size: 44, Cash: 89147.32, Open: 2006.21, Close: 2038.76
# 2021-05-17, BUY EXECUTED --- Price: 2006.21, Cost: 88273.24,Commission: 88.27
# 2021-05-20, SELL CREATED --- Size: 44
# 2021-05-20, SELL EXECUTED --- Price: 2054.65, Cost: 88273.24,Commission: 90.40
# 2021-05-20, OPERATION RESULT --- Gross: 2131.36, Net: 1952.68
# 2021-05-24, BUY CREATED --- Size: 44, Cash: 91100.00, Open: 2031.87, Close: 2051.97
# 2021-05-24, BUY EXECUTED --- Price: 2031.87, Cost: 89402.28,Commission: 89.40
# 2021-05-27, SELL CREATED --- Size: 44
# 2021-05-27, SELL EXECUTED --- Price: 2190.39, Cost: 89402.28,Commission: 96.38
# 2021-05-27, OPERATION RESULT --- Gross: 6974.88, Net: 6789.10
# 2021-05-28, BUY CREATED --- Size: 44, Cash: 97889.10, Open: 2220.06, Close: 2209.2
# 2021-05-28, BUY EXECUTED --- Price: 2220.06, Cost: 97682.64,Commission: 97.68
# 2021-06-03, SELL CREATED --- Size: 44
# 2021-06-03, SELL EXECUTED --- Price: 2199.29, Cost: 97682.64,Commission: 96.77
# 2021-06-03, OPERATION RESULT --- Gross: -913.88, Net: -1108.33
# 2021-06-04, BUY CREATED --- Size: 44, Cash: 96780.77, Open: 2194.34, Close: 2230.5
# 2021-06-04, BUY EXECUTED --- Price: 2194.34, Cost: 96550.96,Commission: 96.55
# 2021-06-09, SELL CREATED --- Size: 44
# 2021-06-09, SELL EXECUTED --- Price: 2171.55, Cost: 96550.96,Commission: 95.55
# 2021-06-09, OPERATION RESULT --- Gross: -1002.76, Net: -1194.86
# 2021-06-10, BUY CREATED --- Size: 43, Cash: 95585.91, Open: 2174.52, Close: 2217.6
# 2021-06-10, BUY EXECUTED --- Price: 2174.52, Cost: 93504.36,Commission: 93.50
# 2021-06-11, SELL CREATED --- Size: 43
# 2021-06-11, SELL EXECUTED --- Price: 2218.11, Cost: 93504.36,Commission: 95.38
# 2021-06-11, OPERATION RESULT --- Gross: 1874.37, Net: 1685.49
# 2021-06-21, BUY CREATED --- Size: 47, Cash: 97271.40, Open: 2065.55, Close: 2062.22
# 2021-06-21, BUY EXECUTED --- Price: 2065.55, Cost: 97080.85,Commission: 97.08
# 2021-06-23, SELL CREATED --- Size: 47
# 2021-06-23, SELL EXECUTED --- Price: 2060.60, Cost: 97080.85,Commission: 96.85
# 2021-06-23, OPERATION RESULT --- Gross: -232.65, Net: -426.58
# 2021-06-24, BUY CREATED --- Size: 47, Cash: 96844.82, Open: 2020.98, Close: 2048.76
# 2021-06-24, BUY EXECUTED --- Price: 2020.98, Cost: 94986.06,Commission: 94.99
# 2021-07-09, SELL CREATED --- Size: 47
# 2021-07-09, SELL EXECUTED --- Price: 1964.52, Cost: 94986.06,Commission: 92.33
# 2021-07-09, OPERATION RESULT --- Gross: -2653.62, Net: -2840.94
# 2021-07-12, BUY CREATED --- Size: 47, Cash: 94003.88, Open: 1975.55, Close: 1961.0
# 2021-07-12, BUY EXECUTED --- Price: 1975.55, Cost: 92850.85,Commission: 92.85
# 2021-07-13, SELL CREATED --- Size: 47
# 2021-07-13, SELL EXECUTED --- Price: 1968.00, Cost: 92850.85,Commission: 92.50
# 2021-07-13, OPERATION RESULT --- Gross: -354.85, Net: -540.20
# 2021-07-15, BUY CREATED --- Size: 47, Cash: 93463.68, Open: 1955.02, Close: 1997.99
# 2021-07-15, BUY EXECUTED --- Price: 1955.02, Cost: 91885.94,Commission: 91.89
# 2021-07-16, SELL CREATED --- Size: 47
# 2021-07-16, SELL EXECUTED --- Price: 1980.00, Cost: 91885.94,Commission: 93.06
# 2021-07-16, OPERATION RESULT --- Gross: 1174.06, Net: 989.11
# 2021-07-20, BUY CREATED --- Size: 47, Cash: 94452.80, Open: 1975.0, Close: 1980.0
# 2021-07-20, BUY EXECUTED --- Price: 1975.00, Cost: 92825.00,Commission: 92.83
# 2021-07-21, SELL CREATED --- Size: 47
# 2021-07-21, SELL EXECUTED --- Price: 1989.00, Cost: 92825.00,Commission: 93.48
# 2021-07-21, OPERATION RESULT --- Gross: 658.00, Net: 471.69
# 2021-07-22, BUY CREATED --- Size: 48, Cash: 94924.49, Open: 1960.0, Close: 1940.01
# 2021-07-22, BUY EXECUTED --- Price: 1960.00, Cost: 94080.00,Commission: 94.08
# 2021-07-23, SELL CREATED --- Size: 48
# 2021-07-23, SELL EXECUTED --- Price: 1937.82, Cost: 94080.00,Commission: 93.02
# 2021-07-23, OPERATION RESULT --- Gross: -1064.64, Net: -1251.74
# 2021-07-26, BUY CREATED --- Size: 49, Cash: 93672.75, Open: 1879.0, Close: 1804.11
# 2021-07-26, BUY EXECUTED --- Price: 1879.00, Cost: 92071.00,Commission: 92.07
# 2021-07-29, SELL CREATED --- Size: 49
# 2021-07-29, SELL EXECUTED --- Price: 1810.01, Cost: 92071.00,Commission: 88.69
# 2021-07-29, OPERATION RESULT --- Gross: -3380.51, Net: -3561.27
# 2021-08-02, BUY CREATED --- Size: 54, Cash: 90111.48, Open: 1664.0, Close: 1755.0
# 2021-08-02, BUY EXECUTED --- Price: 1664.00, Cost: 89856.00,Commission: 89.86
# 2021-08-05, SELL CREATED --- Size: 54
# 2021-08-05, SELL EXECUTED --- Price: 1692.88, Cost: 89856.00,Commission: 91.42
# 2021-08-05, OPERATION RESULT --- Gross: 1559.52, Net: 1378.25
# 2021-08-06, BUY CREATED --- Size: 54, Cash: 91489.73, Open: 1689.0, Close: 1671.0
# 2021-08-06, BUY EXECUTED --- Price: 1689.00, Cost: 91206.00,Commission: 91.21
# 2021-08-09, SELL CREATED --- Size: 54
# 2021-08-09, SELL EXECUTED --- Price: 1651.00, Cost: 91206.00,Commission: 89.15
# 2021-08-09, OPERATION RESULT --- Gross: -2052.00, Net: -2232.36
# 2021-08-10, BUY CREATED --- Size: 52, Cash: 89257.37, Open: 1700.0, Close: 1799.0
# 2021-08-10, BUY EXECUTED --- Price: 1700.00, Cost: 88400.00,Commission: 88.40
# 2021-08-11, SELL CREATED --- Size: 52
# 2021-08-11, SELL EXECUTED --- Price: 1780.01, Cost: 88400.00,Commission: 92.56
# 2021-08-11, OPERATION RESULT --- Gross: 4160.52, Net: 3979.56
# 2021-08-12, BUY CREATED --- Size: 53, Cash: 93236.93, Open: 1732.0, Close: 1690.0
# 2021-08-12, BUY EXECUTED --- Price: 1732.00, Cost: 91796.00,Commission: 91.80
# 2021-08-18, SELL CREATED --- Size: 53
# 2021-08-18, SELL EXECUTED --- Price: 1624.66, Cost: 91796.00,Commission: 86.11
# 2021-08-18, OPERATION RESULT --- Gross: -5689.02, Net: -5866.92
# 2021-08-19, BUY CREATED --- Size: 53, Cash: 87370.01, Open: 1622.22, Close: 1619.97
# 2021-08-19, BUY EXECUTED --- Price: 1622.22, Cost: 85977.66,Commission: 85.98
# 2021-08-27, SELL CREATED --- Size: 53
# 2021-08-27, SELL EXECUTED --- Price: 1589.00, Cost: 85977.66,Commission: 84.22
# 2021-08-27, OPERATION RESULT --- Gross: -1760.66, Net: -1930.85
# 2021-09-01, BUY CREATED --- Size: 54, Cash: 85439.15, Open: 1559.0, Close: 1622.01
# 2021-09-01, BUY EXECUTED --- Price: 1559.00, Cost: 84186.00,Commission: 84.19
# 2021-09-03, SELL CREATED --- Size: 54
# 2021-09-03, SELL EXECUTED --- Price: 1610.02, Cost: 84186.00,Commission: 86.94
# 2021-09-03, OPERATION RESULT --- Gross: 2755.08, Net: 2583.95
# 2021-09-06, BUY CREATED --- Size: 53, Cash: 88023.11, Open: 1649.0, Close: 1670.67
# 2021-09-06, BUY EXECUTED --- Price: 1649.00, Cost: 87397.00,Commission: 87.40
# 2021-09-07, SELL CREATED --- Size: 53
# 2021-09-07, SELL EXECUTED --- Price: 1661.03, Cost: 87397.00,Commission: 88.03
# 2021-09-07, OPERATION RESULT --- Gross: 637.59, Net: 462.16
# 2021-09-08, BUY CREATED --- Size: 53, Cash: 88485.26, Open: 1660.0, Close: 1633.1
# 2021-09-08, BUY EXECUTED --- Price: 1660.00, Cost: 87980.00,Commission: 87.98
# 2021-09-10, SELL CREATED --- Size: 53
# 2021-09-10, SELL EXECUTED --- Price: 1634.08, Cost: 87980.00,Commission: 86.61
# 2021-09-10, OPERATION RESULT --- Gross: -1373.76, Net: -1548.35
# 2021-09-13, BUY CREATED --- Size: 52, Cash: 86936.92, Open: 1665.0, Close: 1654.0
# 2021-09-13, BUY EXECUTED --- Price: 1665.00, Cost: 86580.00,Commission: 86.58
# 2021-09-14, SELL CREATED --- Size: 52
# 2021-09-14, SELL EXECUTED --- Price: 1659.00, Cost: 86580.00,Commission: 86.27
# 2021-09-14, OPERATION RESULT --- Gross: -312.00, Net: -484.85
# 2021-09-16, BUY CREATED --- Size: 53, Cash: 86452.07, Open: 1603.0, Close: 1638.07
# 2021-09-16, BUY EXECUTED --- Price: 1603.00, Cost: 84959.00,Commission: 84.96
# 2021-09-22, SELL CREATED --- Size: 53
# 2021-09-22, SELL EXECUTED --- Price: 1658.83, Cost: 84959.00,Commission: 87.92
# 2021-09-22, OPERATION RESULT --- Gross: 2958.99, Net: 2786.11
# 2021-09-23, BUY CREATED --- Size: 54, Cash: 89238.18, Open: 1638.0, Close: 1635.0
# 2021-09-23, BUY EXECUTED --- Price: 1638.00, Cost: 88452.00,Commission: 88.45
# 2021-09-27, SELL CREATED --- Size: 54
# 2021-09-27, SELL EXECUTED --- Price: 1750.00, Cost: 88452.00,Commission: 94.50
# 2021-09-27, OPERATION RESULT --- Gross: 6048.00, Net: 5865.05
# 2021-09-28, BUY CREATED --- Size: 51, Cash: 95103.23, Open: 1848.0, Close: 1822.06
# 2021-09-28, BUY EXECUTED --- Price: 1848.00, Cost: 94248.00,Commission: 94.25
# 2021-10-08, SELL CREATED --- Size: 51
# 2021-10-08, SELL EXECUTED --- Price: 1822.42, Cost: 94248.00,Commission: 92.94
# 2021-10-08, OPERATION RESULT --- Gross: -1304.58, Net: -1491.77
# 2021-10-14, BUY CREATED --- Size: 48, Cash: 93611.46, Open: 1928.93, Close: 1911.0
# 2021-10-14, BUY EXECUTED --- Price: 1928.93, Cost: 92588.64,Commission: 92.59
# 2021-10-15, SELL CREATED --- Size: 48
# 2021-10-15, SELL EXECUTED --- Price: 1890.10, Cost: 92588.64,Commission: 90.72
# 2021-10-15, OPERATION RESULT --- Gross: -1863.84, Net: -2047.15
# 2021-10-19, BUY CREATED --- Size: 50, Cash: 91564.31, Open: 1800.0, Close: 1812.18
# 2021-10-19, BUY EXECUTED --- Price: 1800.00, Cost: 90000.00,Commission: 90.00
# Final Portfolio Value: 93524.31

# %%
# Extract inputs for pyfolio
strat = backtest_result[0]
pyfoliozer = strat.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
returns.name = 'Strategy'
returns.head(2)
# Out:
# index
# 2021-01-12 00:00:00+00:00    0.000000
# 2021-01-13 00:00:00+00:00   -0.000986
# Name: Strategy, dtype: float64

# %%
# get benchmark returns
benchmark_rets= stock['returns']
benchmark_rets.index = benchmark_rets.index.tz_localize('UTC') 
benchmark_rets = benchmark_rets.filter(returns.index)
benchmark_rets.name = 'Nifty-50'
benchmark_rets.head(2)
# Out:
# date
# 2021-01-12 00:00:00+00:00    0.028716
# 2021-01-13 00:00:00+00:00    0.001433
# Name: Nifty-50, dtype: float64

# %%
# get performance statistics for strategy
pf.show_perf_stats(returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-01-12</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-20</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>8</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-8.716%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-6.476%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>31.347%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.14</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.39</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.06</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-22.24%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.97</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.20</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.65</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.966%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# plot performance for strategy vs benchmark
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(16, 9),constrained_layout=True)
axes = ax.flatten()

pf.plot_drawdown_periods(returns=returns, ax=axes[0])
axes[0].grid(True)
pf.plot_rolling_returns(returns=returns,
                        factor_returns=benchmark_rets,
                        ax=axes[1], title='Strategy vs Nifty-50')
axes[1].grid(True)
pf.plot_drawdown_underwater(returns=returns, ax=axes[2])
axes[2].grid(True)
pf.plot_rolling_sharpe(returns=returns, ax=axes[3])
axes[3].grid(True)
# fig.suptitle('Strategy vs Nifty-50 (Buy and Hold)', fontsize=16, y=0.990)

plt.grid(True)
plt.legend()
plt.tight_layout()
# plt.savefig('images/chart3', dpi=300)
plt.show()

# %%
# plot performance for strategy vs benchmark
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(16, 9),constrained_layout=True)
axes = ax.flatten()

pf.plot_rolling_beta(returns=returns, factor_returns=benchmark_rets, ax=axes[0])
axes[0].grid(True)

pf.plot_rolling_volatility(returns=returns, factor_returns=benchmark_rets,ax=axes[1])
axes[1].grid(True)

pf.plot_annual_returns(returns=returns, ax=axes[2])
axes[2].grid(True)

pf.plot_monthly_returns_heatmap(returns=returns, ax=axes[3],)
# fig.suptitle('BL Portfolio vs BSE-SENSEX - 2', fontsize=16, y=1.0)


plt.tight_layout()
# plt.savefig('images/chart4', dpi=300)
plt.show()
