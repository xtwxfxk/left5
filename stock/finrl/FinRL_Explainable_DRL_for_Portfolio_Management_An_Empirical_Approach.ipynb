# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/FinRL_Explainable_DRL_for_Portfolio_Management_An_Empirical_Approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Explainable Deep Reinforcement Learning for Portfolio Managemnet: an Emprical Approach.
#
# Tutorials to use FinRL Library to perform explainable portfolio allocation in one [Jupyter Notebook](https://colab.research.google.com/drive/117v2qWo-qPC7OPd7paY1wYkOUywU_DWZ?usp=sharing)
#
# * This tutorial is based on the [portfolio allocation tutorial](https://github.com/AI4Finance-Foundation/FinRL/blob/master/FinRL_portfolio_allocation_NeurIPS_2020.ipynb) in FinRL Library.
# * This blog is based on our paper: Explainable Deep Reinforcement Learning for Portfolio Managemnet: an Emprical Approach
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to empirically explain the trading performance of DRL agents for the portfolio management task.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed portfolio weights that the agent interacts with the
# environment. Each element in the portfolio weights is between [0, 1].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The logorithmic rate of portfolio return when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = ln(v'/v), where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes  an agent’s perception of a market.  Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
# We use Yahoo Finance API as the data source.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install plotly==4.4.1
# !wget https://github.com/plotly/orca/releases/download/v1.2.1/orca-1.2.1-x86_64.AppImage -O /usr/local/bin/orca
# !chmod +x /usr/local/bin/orca
# !apt-get install xvfb libgtk2.0-0 libgconf-2-4
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git
# !pip install PyPortfolioOpt

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl.apps import config
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.drl_agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline, get_baseline_tdx,convert_daily_return_to_pyfolio_ts


# import sys
# sys.path.append("../FinRL-Library")
# Out:
# d:\code\python\pyfolio\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %%
from lutils.stock import LTdxHq

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
# df = YahooDownloader(start_date = '2008-01-01',
#                      end_date = '2021-09-02',
#                      ticker_list = config.DOW_30_TICKER).fetch_data()

# %%
# print(config.DOW_30_TICKER)
# stock_codes = ['603636']
stock_codes = ['600603', '600583', '600582', '600565', '600558', 
               '600551', '600509', '600503', '600488', '600469', 
               '600439', '600433', '600428', '600425', '600387', 
               '600383', '600382', '600369', '600339', '600337', ]
#                '600335', '600326', '600320', '600312', '002666', 
#                '002654', '002641', '002628', '002627', '002620', 
#                '002608', '002593', '002586', '002582', '002566', '002560',]

# %%
ltdxhq = LTdxHq()

indexs = None
dfs = []
for code in stock_codes:
    df = ltdxhq.get_k_data_daily(code, start='2010-01-01')
    
    if indexs is None:
        indexs = df.index
    else:
        indexs = indexs.union(df.index)
    
#     df = df.assign(date = df.index)
#     df = df.assign(day = df.index.weekday)
#     df.date = df.date.dt.strftime('%Y-%m-%d')
    df = df.assign(tic = code)
#     df.index = range(df.shape[0])
    
    dfs.append(df)
    print('----------- over %s min: %s max: %s -----------' % (code, df.index.min(), df.index.max()))

for i, df in enumerate(dfs):
    df = df.reindex(indexs)
    df = df.assign(date = df.index)
    df = df.assign(day = df.index.weekday)
    df.index = range(df.shape[0])
    
    dfs[i] = df.ffill()
    
df = pd.concat(dfs)
# df.index = range(df.shape[0])

ltdxhq.close()
# Out:
# ----------- over 600603 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600583 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600582 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600565 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600558 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600551 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600509 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600503 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600488 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600469 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600439 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600433 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600428 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600425 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600387 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600383 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600382 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600369 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600339 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------
# ----------- over 600337 2010-01-04 00:00:00 2022-01-10 00:00:00 -----------

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

df = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values 
  cov_list.append(covs)

  
df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed portfolio weights that the agent interacts with the environment. Each element in the portfolio weights vector is non-negative and no more than 100%. Also, the sum of elements in each portfolio weight should equal to 100%.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-06-30

# %%
train = data_split(df, '2016-03-01','2021-01-01')

# %%
train
# Out:
#        open  close   high    low      volume       amount     tic       date  \
# 0      4.56   4.68   4.72   4.55   3549436.0   42700748.0  600337 2016-03-01
# 0      5.06   5.08   5.11   4.91   9212573.0   48842344.0  600339 2016-03-01
# 0      6.70   6.85   7.10   6.52  53198120.0  395804800.0  600369 2016-03-01
# 0      5.70   5.88   5.92   5.60  11045916.0  112617592.0  600382 2016-03-01
# 0     10.55  10.32  10.57  10.26  30687064.0  436575520.0  600383 2016-03-01
# ...     ...    ...    ...    ...         ...          ...     ...        ...
# 1181   3.15   3.13   3.15   3.10  10601300.0   33574544.0  600558 2020-12-31
# 1181   2.65   2.65   2.67   2.64  21243702.0   58018176.0  600565 2020-12-31
# 1181   3.00   2.98   3.03   2.97  35283084.0  109164440.0  600582 2020-12-31
# 1181   4.28   4.42   4.46   4.26  25353704.0  112760648.0  600583 2020-12-31
# 1181   4.45   4.52   4.54   4.45   2819550.0   13593350.0  600603 2020-12-31
#
#       day      macd    boll_ub   boll_lb     rsi_30      cci_30      dx_30  \
# 0       1 -0.091808   5.109059  4.392941  43.938384  -39.699215  31.094128
# 0       1 -0.125255   5.294208  4.516792  42.341115   19.864341  25.416840
# 0       1 -0.246513   8.018003  6.697997  42.003578 -180.495478  26.960935
# 0       1 -0.248220   6.807225  5.292775  42.382536  -80.170576  27.159655
# 0       1 -0.081784  12.015784  9.990216  48.945437 -101.356360  27.071676
# ...   ...       ...        ...       ...        ...         ...        ...
# 1181    3 -0.009618   3.309277  2.936723  50.761502   -7.379612   3.167156
# 1181    3 -0.049966   2.880820  2.588180  40.298398 -107.996324  41.754478
# 1181    3 -0.030180   3.201085  2.940915  45.064462 -124.165252   4.816281
# 1181    3 -0.038080   4.555107  4.142893  49.322017  -33.203765   4.349156
# 1181    3 -0.038489   4.910633  4.372367  45.835250  -65.472637   0.023067
#
#       close_30_sma  close_60_sma  \
# 0         4.733667      5.275167
# 0         4.996000      5.998167
# 0         7.437667      8.074500
# 0         6.215333      7.600333
# 0        11.007333     10.507500
# ...            ...           ...
# 1181      3.134000      3.101833
# 1181      2.782333      2.798333
# 1181      3.110667      3.069333
# 1181      4.454667      4.417500
# 1181      4.607333      4.613000
#
#                                                cov_list  \
# 0     [[0.0019272424591115392, 0.0012211666330536422...
# 0     [[0.0019272424591115392, 0.0012211666330536422...
# 0     [[0.0019272424591115392, 0.0012211666330536422...
# 0     [[0.0019272424591115392, 0.0012211666330536422...
# 0     [[0.0019272424591115392, 0.0012211666330536422...
# ...                                                 ...
# 1181  [[0.0006290657157333915, 0.0001802408834369541...
# 1181  [[0.0006290657157333915, 0.0001802408834369541...
# 1181  [[0.0006290657157333915, 0.0001802408834369541...
# 1181  [[0.0006290657157333915, 0.0001802408834369541...
# 1181  [[0.0006290657157333915, 0.0001802408834369541...
#
#                                             return_list
# 0     tic           600337    600339    600369    60...
# 0     tic           600337    600339    600369    60...
# 0     tic           600337    600339    600369    60...
# 0     tic           600337    600339    600369    60...
# 0     tic           600337    600339    600369    60...
# ...                                                 ...
# 1181  tic           600337    600339    600369    60...
# 1181  tic           600337    600339    600369    60...
# 1181  tic           600337    600339    600369    60...
# 1181  tic           600337    600339    600369    60...
# 1181  tic           600337    600339    600369    60...
#
# [23640 rows x 19 columns]

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A portfolio allocation environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then 
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step
        

    """
    metadata = {'render.modes': ['human']}

    def __init__(self, 
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,)) 
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.terminal = False     
        self.turbulence_threshold = turbulence_threshold        
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]

        
    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique())-1

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()
            
            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))           
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")
            
            return self.state, self.reward, self.terminal,{}

        else:
            weights = self.softmax_normalization(actions) 
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].values[0]
            self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            log_portfolio_return = np.log(sum((self.data.close.values / last_day_memory.close.values)*weights))
            # update portfolio value
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])            
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value
            

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False 
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]] 
        return self.state
    
    def render(self, mode='human'):
        return self.state
        
    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output

    
    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']
        
        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 20

# %%
config.TECHNICAL_INDICATORS_LIST
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
# ['daily_variance', 'change', 'log_volume', 'close','day', 'macd', 'rsi_30', 'boll_ub', 'dx_30']
# ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'boll_ub', 'dx_30', 'close_30_sma', 'close_60_sma'] # cci_30
tech_indicator_list = ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'boll_ub', 'dx_30', 'close_30_sma', 'close_60_sma']
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, # config.TECHNICAL_INDICATORS_LIST, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-1
    
}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * We use two DRL algorithms in FinRL library PPO andf A2C

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 10, "ent_coef": 0.005, "learning_rate": 0.0004}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 10, 'ent_coef': 0.005, 'learning_rate': 0.0004}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, tb_log_name='a2c', total_timesteps=80000)
# Out:
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.04e+08 |
# |    reward             | 748687.2 |
# |    std                | 0.991    |
# |    value_loss         | 2.02e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:867756.5958545827
# Sharpe:  -0.02044496275001681
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 399      |
# |    iterations         | 200      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.19e+08 |
# |    reward             | 780944.5 |
# |    std                | 0.989    |
# |    value_loss         | 2.23e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:784096.2934800378
# Sharpe:  -0.11523533669109104
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 409      |
# |    iterations         | 300      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.08e+08 |
# |    reward             | 715407.4 |
# |    std                | 0.988    |
# |    value_loss         | 1.78e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:792182.207116573
# Sharpe:  -0.10665737176457032
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 415      |
# |    iterations         | 400      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.48e+08 |
# |    reward             | 971231.2 |
# |    std                | 0.986    |
# |    value_loss         | 3.17e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:847291.7200260303
# Sharpe:  -0.045062573126567335
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 419       |
# |    iterations         | 500       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 499       |
# |    policy_loss        | 1.85e+08  |
# |    reward             | 1242089.1 |
# |    std                | 0.987     |
# |    value_loss         | 5.67e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:801941.4529847247
# Sharpe:  -0.09374699096943923
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 422       |
# |    iterations         | 600       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.59e+08  |
# |    reward             | 1047223.7 |
# |    std                | 0.986     |
# |    value_loss         | 3.7e+13   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 700      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.2e+08  |
# |    reward             | 861106.0 |
# |    std                | 0.985    |
# |    value_loss         | 2.38e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:793577.9988710199
# Sharpe:  -0.10753090967153
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 800       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 799       |
# |    policy_loss        | 1.2e+08   |
# |    reward             | 742958.75 |
# |    std                | 0.984     |
# |    value_loss         | 2.14e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:858470.1439425952
# Sharpe:  -0.030262424746872737
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 900      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -28      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 899      |
# |    policy_loss        | 9.83e+07 |
# |    reward             | 729176.6 |
# |    std                | 0.983    |
# |    value_loss         | 1.6e+13  |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:834579.748529882
# Sharpe:  -0.05700244395655816
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 1000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -28       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 999       |
# |    policy_loss        | 1.32e+08  |
# |    reward             | 858828.56 |
# |    std                | 0.982     |
# |    value_loss         | 2.47e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:869645.1345313617
# Sharpe:  -0.019907556154377542
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 427       |
# |    iterations         | 1100      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -28       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1099      |
# |    policy_loss        | 1.51e+08  |
# |    reward             | 1005846.9 |
# |    std                | 0.98      |
# |    value_loss         | 3.68e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:771370.1888533033
# Sharpe:  -0.13330212123130597
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 428       |
# |    iterations         | 1200      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -28       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.59e+08  |
# |    reward             | 1197906.8 |
# |    std                | 0.979     |
# |    value_loss         | 4.56e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 1300     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 1299     |
# |    policy_loss        | 1.26e+08 |
# |    reward             | 833457.6 |
# |    std                | 0.979    |
# |    value_loss         | 2.61e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:847194.542340879
# Sharpe:  -0.04583657029246362
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 1400     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 1399     |
# |    policy_loss        | 1.05e+08 |
# |    reward             | 739572.8 |
# |    std                | 0.977    |
# |    value_loss         | 2.13e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:843765.6464733711
# Sharpe:  -0.04775280631474644
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 1500     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 1499     |
# |    policy_loss        | 1.28e+08 |
# |    reward             | 858076.3 |
# |    std                | 0.977    |
# |    value_loss         | 2.45e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:852294.0893319577
# Sharpe:  -0.03811087409032013
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 1600     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 1599     |
# |    policy_loss        | 1.07e+08 |
# |    reward             | 717691.2 |
# |    std                | 0.978    |
# |    value_loss         | 1.71e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:821564.9071369667
# Sharpe:  -0.07200990439737837
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 1700     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 1699     |
# |    policy_loss        | 1.42e+08 |
# |    reward             | 927516.6 |
# |    std                | 0.977    |
# |    value_loss         | 2.91e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:862148.4416177856
# Sharpe:  -0.02693259584328358
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 1800      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -27.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1799      |
# |    policy_loss        | 1.8e+08   |
# |    reward             | 1216509.9 |
# |    std                | 0.976     |
# |    value_loss         | 5.45e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:825934.171634954
# Sharpe:  -0.0655670788115379
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 1900      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -27.9     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 1899      |
# |    policy_loss        | 1.56e+08  |
# |    reward             | 1080215.0 |
# |    std                | 0.975     |
# |    value_loss         | 3.79e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 2000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -27.9    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.34e+08 |
# |    reward             | 922410.0 |
# |    std                | 0.975    |
# |    value_loss         | 2.81e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:862014.9722209566
# Sharpe:  -0.023758155295699666
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 2100      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2099      |
# |    policy_loss        | 1.04e+08  |
# |    reward             | 681306.94 |
# |    std                | 0.973     |
# |    value_loss         | 1.86e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:801280.7944671864
# Sharpe:  -0.09336241950358314
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 2200      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2199      |
# |    policy_loss        | 9.82e+07  |
# |    reward             | 724993.2  |
# |    std                | 0.973     |
# |    value_loss         | 1.6e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:806678.0878774079
# Sharpe:  -0.08910968027130291
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 2300      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2299      |
# |    policy_loss        | 1.17e+08  |
# |    reward             | 854424.75 |
# |    std                | 0.973     |
# |    value_loss         | 2.39e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:822086.5241610591
# Sharpe:  -0.07013658926756586
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 2400      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2399      |
# |    policy_loss        | 1.61e+08  |
# |    reward             | 1011140.2 |
# |    std                | 0.972     |
# |    value_loss         | 3.75e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:808137.1391742129
# Sharpe:  -0.08626934319132
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 2500      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2499      |
# |    policy_loss        | 1.65e+08  |
# |    reward             | 1199128.4 |
# |    std                | 0.973     |
# |    value_loss         | 4.73e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 2600     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 2599     |
# |    policy_loss        | 1.23e+08 |
# |    reward             | 838237.8 |
# |    std                | 0.972    |
# |    value_loss         | 2.71e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:861117.8521275575
# Sharpe:  -0.025753195811930765
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 2700      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2699      |
# |    policy_loss        | 1.21e+08  |
# |    reward             | 726144.06 |
# |    std                | 0.971     |
# |    value_loss         | 2.22e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:838414.1940034769
# Sharpe:  -0.0536116106693469
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 2800      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 2799      |
# |    policy_loss        | 1.05e+08  |
# |    reward             | 773106.06 |
# |    std                | 0.969     |
# |    value_loss         | 1.93e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:800892.6406989803
# Sharpe:  -0.09424070897643197
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 2900     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 2899     |
# |    policy_loss        | 1.05e+08 |
# |    reward             | 732309.4 |
# |    std                | 0.97     |
# |    value_loss         | 1.81e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:767488.9042564031
# Sharpe:  -0.13364149722862226
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 3000     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -27.8    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 2999     |
# |    policy_loss        | 1.32e+08 |
# |    reward             | 900243.1 |
# |    std                | 0.971    |
# |    value_loss         | 2.98e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:830897.6666649699
# Sharpe:  -0.06077743006000093
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 3100      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3099      |
# |    policy_loss        | 1.83e+08  |
# |    reward             | 1234338.8 |
# |    std                | 0.971     |
# |    value_loss         | 5.42e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:792807.7530722064
# Sharpe:  -0.1053274488509528
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 3200      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3199      |
# |    policy_loss        | 1.51e+08  |
# |    reward             | 1060690.4 |
# |    std                | 0.971     |
# |    value_loss         | 3.74e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 3300      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -27.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3299      |
# |    policy_loss        | 1.15e+08  |
# |    reward             | 844802.9  |
# |    std                | 0.97      |
# |    value_loss         | 2.36e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:807200.9259113407
# Sharpe:  -0.0897223209512019
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 3400      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3399      |
# |    policy_loss        | 1.07e+08  |
# |    reward             | 731985.4  |
# |    std                | 0.969     |
# |    value_loss         | 2.15e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:831790.4659950114
# Sharpe:  -0.06165114649942103
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 3500     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 3499     |
# |    policy_loss        | 9.55e+07 |
# |    reward             | 687571.9 |
# |    std                | 0.969    |
# |    value_loss         | 1.61e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:776451.004523037
# Sharpe:  -0.12673351555857318
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 3600     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 3599     |
# |    policy_loss        | 1.08e+08 |
# |    reward             | 780714.3 |
# |    std                | 0.967    |
# |    value_loss         | 2.06e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:781646.2472758553
# Sharpe:  -0.12020351854190947
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 3700     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -27.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 3699     |
# |    policy_loss        | 1.55e+08 |
# |    reward             | 985442.5 |
# |    std                | 0.968    |
# |    value_loss         | 3.59e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:873769.6725358585
# Sharpe:  -0.015526776309258286
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 3800      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3799      |
# |    policy_loss        | 1.69e+08  |
# |    reward             | 1249457.4 |
# |    std                | 0.967     |
# |    value_loss         | 4.95e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 3900      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3899      |
# |    policy_loss        | 1.16e+08  |
# |    reward             | 822858.25 |
# |    std                | 0.966     |
# |    value_loss         | 2.66e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:836949.6803659027
# Sharpe:  -0.05652677558297587
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4000      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -27.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 3999      |
# |    policy_loss        | 1.1e+08   |
# |    reward             | 722299.06 |
# |    std                | 0.965     |
# |    value_loss         | 2.16e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:807805.8467924987
# Sharpe:  -0.09475376964663515
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 4100     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 4099     |
# |    policy_loss        | 1.05e+08 |
# |    reward             | 783276.5 |
# |    std                | 0.964    |
# |    value_loss         | 2.14e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:796235.9379666272
# Sharpe:  -0.10708133791592499
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4200      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4199      |
# |    policy_loss        | 1.12e+08  |
# |    reward             | 766660.3  |
# |    std                | 0.964     |
# |    value_loss         | 2.02e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:905887.0479895797
# Sharpe:  0.017482928008944156
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4300      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4299      |
# |    policy_loss        | 1.33e+08  |
# |    reward             | 922252.94 |
# |    std                | 0.963     |
# |    value_loss         | 3.08e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:825234.9143180598
# Sharpe:  -0.070952897422459
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4400      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4399      |
# |    policy_loss        | 1.85e+08  |
# |    reward             | 1245952.8 |
# |    std                | 0.962     |
# |    value_loss         | 5.6e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:897489.9404133231
# Sharpe:  0.009928951116692213
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4500      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4499      |
# |    policy_loss        | 1.5e+08   |
# |    reward             | 1044335.0 |
# |    std                | 0.962     |
# |    value_loss         | 3.76e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4600      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4599      |
# |    policy_loss        | 1.13e+08  |
# |    reward             | 797043.94 |
# |    std                | 0.961     |
# |    value_loss         | 2.14e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:739399.0790795861
# Sharpe:  -0.17359225962427208
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4700      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.06e+08  |
# |    reward             | 684006.4  |
# |    std                | 0.962     |
# |    value_loss         | 1.87e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:789635.9312353694
# Sharpe:  -0.11039560469385395
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4800      |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4799      |
# |    policy_loss        | 9.34e+07  |
# |    reward             | 660932.75 |
# |    std                | 0.963     |
# |    value_loss         | 1.47e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:789720.4291376846
# Sharpe:  -0.11120024884055592
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 4900     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 4899     |
# |    policy_loss        | 1.2e+08  |
# |    reward             | 811696.1 |
# |    std                | 0.963    |
# |    value_loss         | 2.29e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:834072.1696502379
# Sharpe:  -0.05696926643481125
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5000      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 4999      |
# |    policy_loss        | 1.54e+08  |
# |    reward             | 988697.56 |
# |    std                | 0.961     |
# |    value_loss         | 3.7e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:827627.4484964029
# Sharpe:  -0.06516923297275105
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5100      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 51000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 5099      |
# |    policy_loss        | 1.81e+08  |
# |    reward             | 1236430.8 |
# |    std                | 0.962     |
# |    value_loss         | 5.03e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5200      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 52000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 5199      |
# |    policy_loss        | 1.31e+08  |
# |    reward             | 877226.75 |
# |    std                | 0.963     |
# |    value_loss         | 2.93e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:886686.9099010533
# Sharpe:  -0.0025973073357333245
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5300      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 53000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.32e+08  |
# |    reward             | 792818.06 |
# |    std                | 0.962     |
# |    value_loss         | 2.61e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:916080.7042209472
# Sharpe:  0.0292626523213028
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 5400     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 5399     |
# |    policy_loss        | 1.01e+08 |
# |    reward             | 740770.6 |
# |    std                | 0.962    |
# |    value_loss         | 1.84e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:801362.2440668498
# Sharpe:  -0.0947940014209507
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 5500     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 55000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 5499     |
# |    policy_loss        | 9.85e+07 |
# |    reward             | 713217.9 |
# |    std                | 0.962    |
# |    value_loss         | 1.8e+13  |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:882168.2721241124
# Sharpe:  -0.005343052242214518
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5600      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 56000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 5599      |
# |    policy_loss        | 1.3e+08   |
# |    reward             | 892362.75 |
# |    std                | 0.962     |
# |    value_loss         | 2.91e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:828720.0967793694
# Sharpe:  -0.06391141785711026
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 5700      |
# |    time_elapsed       | 132       |
# |    total_timesteps    | 57000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 5699      |
# |    policy_loss        | 1.91e+08  |
# |    reward             | 1271895.9 |
# |    std                | 0.963     |
# |    value_loss         | 5.6e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:897855.1281367528
# Sharpe:  0.01167498611432154
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 5800      |
# |    time_elapsed       | 134       |
# |    total_timesteps    | 58000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 5799      |
# |    policy_loss        | 1.52e+08  |
# |    reward             | 1035660.2 |
# |    std                | 0.961     |
# |    value_loss         | 3.77e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 5900     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 59000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 5899     |
# |    policy_loss        | 1.32e+08 |
# |    reward             | 910193.7 |
# |    std                | 0.962    |
# |    value_loss         | 2.86e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:862260.0805763936
# Sharpe:  -0.026237306762851784
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 6000     |
# |    time_elapsed       | 139      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 5999     |
# |    policy_loss        | 1.16e+08 |
# |    reward             | 770374.2 |
# |    std                | 0.963    |
# |    value_loss         | 2.26e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:858002.5953034519
# Sharpe:  -0.030929189023467123
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6100      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 61000     |
# | train/                |           |
# |    entropy_loss       | -27.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 6099      |
# |    policy_loss        | 1.01e+08  |
# |    reward             | 699356.06 |
# |    std                | 0.963     |
# |    value_loss         | 1.74e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:844805.3582826481
# Sharpe:  -0.04426452390126091
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 6200     |
# |    time_elapsed       | 143      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 6199     |
# |    policy_loss        | 1.31e+08 |
# |    reward             | 849463.6 |
# |    std                | 0.963    |
# |    value_loss         | 2.57e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:866307.8702256089
# Sharpe:  -0.02243457843560241
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 430        |
# |    iterations         | 6300       |
# |    time_elapsed       | 146        |
# |    total_timesteps    | 63000      |
# | train/                |            |
# |    entropy_loss       | -27.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0004     |
# |    n_updates          | 6299       |
# |    policy_loss        | 1.37e+08   |
# |    reward             | 1031406.06 |
# |    std                | 0.96       |
# |    value_loss         | 3.68e+13   |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:816161.0036152581
# Sharpe:  -0.07811277842733594
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 6400      |
# |    time_elapsed       | 148       |
# |    total_timesteps    | 64000     |
# | train/                |           |
# |    entropy_loss       | -27.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.68e+08  |
# |    reward             | 1197705.0 |
# |    std                | 0.96      |
# |    value_loss         | 4.77e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 431      |
# |    iterations         | 6500     |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 65000    |
# | train/                |          |
# |    entropy_loss       | -27.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 6499     |
# |    policy_loss        | 1.33e+08 |
# |    reward             | 863479.1 |
# |    std                | 0.961    |
# |    value_loss         | 2.77e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:867814.7527799355
# Sharpe:  -0.01936486282225984
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6600      |
# |    time_elapsed       | 153       |
# |    total_timesteps    | 66000     |
# | train/                |           |
# |    entropy_loss       | -27.5     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 6599      |
# |    policy_loss        | 1.24e+08  |
# |    reward             | 777344.0  |
# |    std                | 0.959     |
# |    value_loss         | 2.68e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:937181.3512618421
# Sharpe:  0.0515882855104506
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 6700     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 67000    |
# | train/                |          |
# |    entropy_loss       | -27.5    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 6699     |
# |    policy_loss        | 1.17e+08 |
# |    reward             | 829457.9 |
# |    std                | 0.958    |
# |    value_loss         | 2.25e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:846758.1619674073
# Sharpe:  -0.04437955948787103
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 6800     |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -27.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 6799     |
# |    policy_loss        | 1.04e+08 |
# |    reward             | 727338.7 |
# |    std                | 0.957    |
# |    value_loss         | 2e+13    |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:814283.9804742828
# Sharpe:  -0.08188853026409942
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 6900     |
# |    time_elapsed       | 160      |
# |    total_timesteps    | 69000    |
# | train/                |          |
# |    entropy_loss       | -27.5    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 6899     |
# |    policy_loss        | 1.28e+08 |
# |    reward             | 865233.5 |
# |    std                | 0.956    |
# |    value_loss         | 2.79e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:837077.9521453588
# Sharpe:  -0.05333437778699266
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7000      |
# |    time_elapsed       | 162       |
# |    total_timesteps    | 70000     |
# | train/                |           |
# |    entropy_loss       | -27.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 6999      |
# |    policy_loss        | 1.73e+08  |
# |    reward             | 1231839.1 |
# |    std                | 0.956     |
# |    value_loss         | 5.22e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:747734.1743944531
# Sharpe:  -0.15985179670309427
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7100      |
# |    time_elapsed       | 164       |
# |    total_timesteps    | 71000     |
# | train/                |           |
# |    entropy_loss       | -27.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 7099      |
# |    policy_loss        | 1.45e+08  |
# |    reward             | 1045818.0 |
# |    std                | 0.956     |
# |    value_loss         | 3.83e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 7200     |
# |    time_elapsed       | 167      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -27.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 7199     |
# |    policy_loss        | 1.16e+08 |
# |    reward             | 875929.7 |
# |    std                | 0.954    |
# |    value_loss         | 2.6e+13  |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:855127.7174492336
# Sharpe:  -0.034644895031600176
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 7300     |
# |    time_elapsed       | 169      |
# |    total_timesteps    | 73000    |
# | train/                |          |
# |    entropy_loss       | -27.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 7299     |
# |    policy_loss        | 1.21e+08 |
# |    reward             | 760966.8 |
# |    std                | 0.954    |
# |    value_loss         | 2.19e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:818400.2566995546
# Sharpe:  -0.07607750924444603
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 7400     |
# |    time_elapsed       | 171      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -27.4    |
# |    explained_variance | 2.98e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 7399     |
# |    policy_loss        | 8.79e+07 |
# |    reward             | 594607.3 |
# |    std                | 0.955    |
# |    value_loss         | 1.38e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:750128.7922815847
# Sharpe:  -0.15635503089272215
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 7500     |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 75000    |
# | train/                |          |
# |    entropy_loss       | -27.4    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0004   |
# |    n_updates          | 7499     |
# |    policy_loss        | 1.18e+08 |
# |    reward             | 807007.7 |
# |    std                | 0.954    |
# |    value_loss         | 2.36e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:814099.3357095079
# Sharpe:  -0.08096867363992302
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7600      |
# |    time_elapsed       | 176       |
# |    total_timesteps    | 76000     |
# | train/                |           |
# |    entropy_loss       | -27.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 7599      |
# |    policy_loss        | 1.42e+08  |
# |    reward             | 1009951.2 |
# |    std                | 0.953     |
# |    value_loss         | 3.51e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:831852.0734620125
# Sharpe:  -0.0597962535709859
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7700      |
# |    time_elapsed       | 178       |
# |    total_timesteps    | 77000     |
# | train/                |           |
# |    entropy_loss       | -27.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 7699      |
# |    policy_loss        | 1.64e+08  |
# |    reward             | 1135133.4 |
# |    std                | 0.951     |
# |    value_loss         | 4.66e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7800      |
# |    time_elapsed       | 181       |
# |    total_timesteps    | 78000     |
# | train/                |           |
# |    entropy_loss       | -27.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 7799      |
# |    policy_loss        | 1.39e+08  |
# |    reward             | 817604.44 |
# |    std                | 0.951     |
# |    value_loss         | 2.55e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:833933.6679046917
# Sharpe:  -0.05675951907914675
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7900      |
# |    time_elapsed       | 183       |
# |    total_timesteps    | 79000     |
# | train/                |           |
# |    entropy_loss       | -27.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 7899      |
# |    policy_loss        | 1.1e+08   |
# |    reward             | 703430.56 |
# |    std                | 0.951     |
# |    value_loss         | 2.07e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:824772.2012894184
# Sharpe:  -0.06581100297249622
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8000      |
# |    time_elapsed       | 185       |
# |    total_timesteps    | 80000     |
# | train/                |           |
# |    entropy_loss       | -27.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0004    |
# |    n_updates          | 7999      |
# |    policy_loss        | 1.01e+08  |
# |    reward             | 733204.06 |
# |    std                | 0.95      |
# |    value_loss         | 1.82e+13  |
# -------------------------------------

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.001, 'batch_size': 128}
# Using cuda device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=80000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:885204.2534107344
# Sharpe:  -0.0028755618583255465
# =================================
# ---------------------------------
# | time/              |          |
# |    fps             | 552      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 786230.7 |
# ---------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:807152.7900527051
# Sharpe:  -0.08818841223789489
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:853899.9003908287
# Sharpe:  -0.03564806028229573
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 1.481385e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.16e+14     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -8.38e-06    |
# |    reward               | 808597.5     |
# |    std                  | 1            |
# |    value_loss           | 2.35e+14     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:775098.7410163817
# Sharpe:  -0.12870677948170212
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:821774.1652510182
# Sharpe:  -0.0736928360210737
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 469           |
# |    iterations           | 3             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.7083948e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.23e+14      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -9.74e-06     |
# |    reward               | 1175521.8     |
# |    std                  | 1             |
# |    value_loss           | 2.45e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:790890.1217431236
# Sharpe:  -0.10595282438501341
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 1.44355e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.14e+14    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -8.5e-06    |
# |    reward               | 831587.44   |
# |    std                  | 1           |
# |    value_loss           | 2.2e+14     |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:781889.6422765946
# Sharpe:  -0.11828902881167672
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:804328.4469152896
# Sharpe:  -0.09384980778206863
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 456           |
# |    iterations           | 5             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 2.0692823e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.05e+14      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -1.29e-05     |
# |    reward               | 789403.75     |
# |    std                  | 1             |
# |    value_loss           | 2.1e+14       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:831727.9832408609
# Sharpe:  -0.06028891137515929
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:865641.8840872644
# Sharpe:  -0.02283302576584594
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 451           |
# |    iterations           | 6             |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.4988473e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.15e+14      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -7.83e-06     |
# |    reward               | 971919.2      |
# |    std                  | 1             |
# |    value_loss           | 2.3e+14       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:773340.8014711686
# Sharpe:  -0.13011863905561344
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:888416.6052272329
# Sharpe:  0.0019876056224542435
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 448           |
# |    iterations           | 7             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.4377292e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.26e+14      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -7.95e-06     |
# |    reward               | 1111570.0     |
# |    std                  | 1             |
# |    value_loss           | 2.45e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:747428.5638358596
# Sharpe:  -0.16234531287636855
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 445           |
# |    iterations           | 8             |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.5017577e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.11e+14      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -8.53e-06     |
# |    reward               | 764908.0      |
# |    std                  | 1             |
# |    value_loss           | 2.22e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:867070.6014858168
# Sharpe:  -0.0211811202777319
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:750160.259025419
# Sharpe:  -0.15757239320494035
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 444           |
# |    iterations           | 9             |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.4028046e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.08e+14      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -7.55e-06     |
# |    reward               | 717872.0      |
# |    std                  | 1             |
# |    value_loss           | 2.18e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:906622.9267919232
# Sharpe:  0.020043173300467204
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:834015.5713071348
# Sharpe:  -0.05838079675114887
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 10          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 2.05182e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.11e+14    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -1.25e-05   |
# |    reward               | 1078874.1   |
# |    std                  | 1           |
# |    value_loss           | 2.29e+14    |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:834972.165457614
# Sharpe:  -0.05861703163196605
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:912123.1517284125
# Sharpe:  0.027481872930560047
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 443           |
# |    iterations           | 11            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.6152626e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.18e+14      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -9.87e-06     |
# |    reward               | 972625.56     |
# |    std                  | 1             |
# |    value_loss           | 2.37e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:771897.0145437997
# Sharpe:  -0.1302045940694643
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 443           |
# |    iterations           | 12            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.3562385e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.1e+14       |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -7.81e-06     |
# |    reward               | 809847.7      |
# |    std                  | 1             |
# |    value_loss           | 2.22e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:869072.4290116053
# Sharpe:  -0.020197676442493734
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:839376.6801700256
# Sharpe:  -0.05192845839447212
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 442           |
# |    iterations           | 13            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.5512342e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.15e+14      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -9.09e-06     |
# |    reward               | 731640.75     |
# |    std                  | 1             |
# |    value_loss           | 2.35e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:837424.6145234313
# Sharpe:  -0.05393270150232117
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:921331.0994542406
# Sharpe:  0.03617196683219092
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 441           |
# |    iterations           | 14            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.4377292e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.32e+14      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -7.77e-06     |
# |    reward               | 999280.2      |
# |    std                  | 1             |
# |    value_loss           | 2.46e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:835190.4013943165
# Sharpe:  -0.0569570733644295
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 441           |
# |    iterations           | 15            |
# |    time_elapsed         | 69            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.6705599e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.18e+14      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -9.7e-06      |
# |    reward               | 745546.75     |
# |    std                  | 1             |
# |    value_loss           | 2.32e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:750883.4950121308
# Sharpe:  -0.15859766916045304
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:775099.5802536757
# Sharpe:  -0.12706846123744606
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 439           |
# |    iterations           | 16            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.4639227e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 9.82e+13      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -8.29e-06     |
# |    reward               | 817347.8      |
# |    std                  | 1             |
# |    value_loss           | 2.08e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:879260.6375033689
# Sharpe:  -0.009724856036481062
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:778687.9109918548
# Sharpe:  -0.12159442528125128
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 439           |
# |    iterations           | 17            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 2.0954758e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.27e+14      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -1.44e-05     |
# |    reward               | 874064.75     |
# |    std                  | 1             |
# |    value_loss           | 2.46e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:839029.3918190973
# Sharpe:  -0.05292390939194164
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:823665.1361919226
# Sharpe:  -0.06932261225687396
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 18            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.9441359e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.17e+14      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -1.31e-05     |
# |    reward               | 1183455.4     |
# |    std                  | 1             |
# |    value_loss           | 2.3e+14       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:776733.0143811004
# Sharpe:  -0.12555529182454667
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 439           |
# |    iterations           | 19            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 1.5395926e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.08e+14      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -7.71e-06     |
# |    reward               | 758924.06     |
# |    std                  | 1             |
# |    value_loss           | 2.24e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:738073.4922272466
# Sharpe:  -0.1735284623663546
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:908343.5597701002
# Sharpe:  0.022083059196902823
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 20            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.7054845e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.05e+14      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -1.03e-05     |
# |    reward               | 853490.4      |
# |    std                  | 1             |
# |    value_loss           | 2.09e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:878093.0822207009
# Sharpe:  -0.010722690083943602
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:836321.3229628236
# Sharpe:  -0.0565140995389914
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 21           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 1.405715e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.3e+14      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -7.26e-06    |
# |    reward               | 1033929.44   |
# |    std                  | 1            |
# |    value_loss           | 2.57e+14     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:886335.8898526926
# Sharpe:  -0.0013914434448922162
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:838578.6970468595
# Sharpe:  -0.05362865463333651
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 22            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 1.6996637e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -4.77e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.21e+14      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -1.03e-05     |
# |    reward               | 1151643.9     |
# |    std                  | 1             |
# |    value_loss           | 2.4e+14       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:914350.1918167361
# Sharpe:  0.02874307223244603
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 23            |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.2543751e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.13e+14      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -6.76e-06     |
# |    reward               | 804140.9      |
# |    std                  | 1             |
# |    value_loss           | 2.18e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:877571.659928638
# Sharpe:  -0.009451028819443614
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:817159.5603754544
# Sharpe:  -0.07757244440364396
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 24            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.4115358e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.27e+14      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -7.71e-06     |
# |    reward               | 624835.44     |
# |    std                  | 1             |
# |    value_loss           | 2.65e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:805956.1271799095
# Sharpe:  -0.09015829661889464
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:848499.5576097673
# Sharpe:  -0.041900523567330074
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 25            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 1.6705599e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.19e+14      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -9.95e-06     |
# |    reward               | 1100009.9     |
# |    std                  | 1             |
# |    value_loss           | 2.34e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:830404.2091452503
# Sharpe:  -0.06237027138639702
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:746133.2330906183
# Sharpe:  -0.16559075855758912
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 26           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 1.816079e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.2e+14      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -1.01e-05    |
# |    reward               | 1014758.5    |
# |    std                  | 1            |
# |    value_loss           | 2.3e+14      |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:890869.2240090728
# Sharpe:  0.001734116682432793
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 437           |
# |    iterations           | 27            |
# |    time_elapsed         | 126           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.8830178e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 9.76e+13      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -1.02e-05     |
# |    reward               | 750072.1      |
# |    std                  | 1             |
# |    value_loss           | 1.92e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:871070.6267365222
# Sharpe:  -0.016304534983786645
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:791182.3559360354
# Sharpe:  -0.1059286951502307
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 437           |
# |    iterations           | 28            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.7462298e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.11e+14      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -1.01e-05     |
# |    reward               | 717651.7      |
# |    std                  | 1             |
# |    value_loss           | 2.39e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:852657.6164229377
# Sharpe:  -0.03828302546406942
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:779923.7638070334
# Sharpe:  -0.12229006013630475
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 436            |
# |    iterations           | 29             |
# |    time_elapsed         | 135            |
# |    total_timesteps      | 59392          |
# | train/                  |                |
# |    approx_kl            | 1.46683306e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.001          |
# |    loss                 | 1.29e+14       |
# |    n_updates            | 480            |
# |    policy_gradient_loss | -8.4e-06       |
# |    reward               | 976603.4       |
# |    std                  | 1              |
# |    value_loss           | 2.42e+14       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:794902.7270775666
# Sharpe:  -0.10520399771076987
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 30            |
# |    time_elapsed         | 140           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 1.4755642e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.19e+14      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -8.51e-06     |
# |    reward               | 768892.4      |
# |    std                  | 1             |
# |    value_loss           | 2.26e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:758060.8985023119
# Sharpe:  -0.14894493046885102
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:948570.7904314953
# Sharpe:  0.06325639762772464
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 31           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 1.731678e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 9.66e+13     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -9.72e-06    |
# |    reward               | 772818.25    |
# |    std                  | 1            |
# |    value_loss           | 1.92e+14     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:871134.0075235905
# Sharpe:  -0.018568965269276917
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:894809.8448824923
# Sharpe:  0.008341784979838476
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 32            |
# |    time_elapsed         | 150           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 1.7869752e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.29e+14      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -1.09e-05     |
# |    reward               | 831101.56     |
# |    std                  | 1             |
# |    value_loss           | 2.63e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:776386.7338183115
# Sharpe:  -0.12489893824548386
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:894511.7914155372
# Sharpe:  0.008809495146230962
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 33            |
# |    time_elapsed         | 154           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.6822014e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.28e+14      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -9.2e-06      |
# |    reward               | 1203469.1     |
# |    std                  | 1             |
# |    value_loss           | 2.54e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:782142.5019863258
# Sharpe:  -0.1173819280807814
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 34            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 1.8277206e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.15e+14      |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -1.1e-05      |
# |    reward               | 848215.5      |
# |    std                  | 1             |
# |    value_loss           | 2.29e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:857551.0774311348
# Sharpe:  -0.03145714183983129
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:869491.8340857502
# Sharpe:  -0.02288148133924273
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 35           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 1.792796e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.04e+14     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -1.1e-05     |
# |    reward               | 942864.1     |
# |    std                  | 1            |
# |    value_loss           | 2.13e+14     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:849956.0227147546
# Sharpe:  -0.04032707619876713
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:747536.5659314664
# Sharpe:  -0.1607907337186336
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 36            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 1.6618287e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.2e+14       |
# |    n_updates            | 550           |
# |    policy_gradient_loss | -9.88e-06     |
# |    reward               | 948053.7      |
# |    std                  | 1             |
# |    value_loss           | 2.38e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:866716.9445910665
# Sharpe:  -0.02262754077600209
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:875976.870875846
# Sharpe:  -0.012227545276173219
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 37            |
# |    time_elapsed         | 173           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 1.6822014e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.14e+14      |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -9.42e-06     |
# |    reward               | 1115852.0     |
# |    std                  | 1             |
# |    value_loss           | 2.31e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:773911.9630168545
# Sharpe:  -0.1285377279003897
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 38           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 1.990702e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.11e+14     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -1.21e-05    |
# |    reward               | 775884.25    |
# |    std                  | 1            |
# |    value_loss           | 2.23e+14     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:895615.2117064517
# Sharpe:  0.008737456591511737
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:874776.9618464308
# Sharpe:  -0.013592710462532766
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 39            |
# |    time_elapsed         | 182           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 1.8713763e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.24e+14      |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -1.13e-05     |
# |    reward               | 721518.94     |
# |    std                  | 1             |
# |    value_loss           | 2.39e+14      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:914750.4323837761
# Sharpe:  0.028289155752270076
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:731910.3962930263
# Sharpe:  -0.18136795842914072
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 40            |
# |    time_elapsed         | 187           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.7520506e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.23e+14      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -1.08e-05     |
# |    reward               | 1056703.0     |
# |    std                  | 1             |
# |    value_loss           | 2.5e+14       |
# -------------------------------------------

# %% [markdown]
# ## Back-Testing
# Assume that we have $1,000,000 initial capital at 2020-01-01. We use the PPO, A2C, SVM, Linear Regression, Decision Tree, Random Foreset models to trade Dow jones 30 constituent stocks.

# %%
trade = data_split(df,'2021-01-01', '2022-01-01')
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)

# %%
import torch
# %matplotlib inline
import plotly.express as px

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
import pandas as pd
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import objective_functions
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
import pyfolio
# %matplotlib inline
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline, get_baseline_tdx,convert_daily_return_to_pyfolio_ts

baseline_df = get_baseline_tdx(
        ticker="600558", 
        start = '2021-01-01',
        end =  '2022-01-01')

baseline_df["date"] = baseline_df.index # pd.to_datetime(baseline_df["date"], format="%Y-%m-%d")
baseline_df.index = range(baseline_df.shape[0])

baseline_df_stats = backtest_stats(baseline_df, value_col_name = 'close')
baseline_returns = get_daily_return(baseline_df, value_col_name="close")

dji_cumpod =(baseline_returns+1).cumprod()-1
# Out:
# Annual return          0.174447
# Cumulative returns     0.167722
# Annual volatility      0.299958
# Sharpe ratio           0.688106
# Calmar ratio           0.802054
# Stability              0.626307
# Max drawdown          -0.217500
# Omega ratio            1.121906
# Sortino ratio          0.989181
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.099549
# Daily value at risk   -0.036972
# dtype: float64

# %%
from pyfolio import timeseries

df_daily_return_a2c, df_actions_a2c = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
df_daily_return_ppo, df_actions_ppo = DRLAgent.DRL_prediction(model=trained_ppo,
                        environment = e_trade_gym)
time_ind = pd.Series(df_daily_return_a2c.date)
a2c_cumpod =(df_daily_return_a2c.daily_return+1).cumprod()-1
ppo_cumpod =(df_daily_return_ppo.daily_return+1).cumprod()-1
DRL_strat_a2c = convert_daily_return_to_pyfolio_ts(df_daily_return_a2c)
DRL_strat_ppo = convert_daily_return_to_pyfolio_ts(df_daily_return_ppo)

perf_func = timeseries.perf_stats 
perf_stats_all_a2c = perf_func( returns=DRL_strat_a2c, 
                              factor_returns=DRL_strat_a2c, 
                                positions=None, transactions=None, turnover_denom="AGB")
perf_stats_all_ppo = perf_func( returns=DRL_strat_ppo, 
                              factor_returns=DRL_strat_ppo, 
                                positions=None, transactions=None, turnover_denom="AGB")
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1119330.4934018687
# Sharpe:  0.6988768978743869
# =================================
# hit end!
# =================================
# begin_total_asset:1000000
# end_total_asset:1126131.9351197474
# Sharpe:  0.7445796004986305
# =================================
# hit end!

# %%
def extract_weights(drl_actions_list):
  a2c_weight_df = {'date':[], 'weights':[]}
  for i in range(len(drl_actions_list)):
    date = drl_actions_list.index[i]
    tic_list = list(drl_actions_list.columns)
    weights_list = drl_actions_list.reset_index()[list(drl_actions_list.columns)].iloc[i].values
    weight_dict = {'tic':[], 'weight':[]}
    for j in range(len(tic_list)):
      weight_dict['tic'] += [tic_list[j]]
      weight_dict['weight'] += [weights_list[j]]

    a2c_weight_df['date'] += [date]
    a2c_weight_df['weights'] += [pd.DataFrame(weight_dict)]

  a2c_weights = pd.DataFrame(a2c_weight_df)
  return a2c_weights

a2c_weights = extract_weights(df_actions_a2c)
ppo_weights = extract_weights(df_actions_ppo)

# %% [markdown]
# ## Machine Learning Models
#
# We trained the machine learning models with technical indicators: MACD, RSI, CCI, DX

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor 

def prepare_data(trainData):
  train_date = sorted(set(trainData.date.values))
  X = []
  for i in range(0, len(train_date) - 1):
    d = train_date[i]
    d_next = train_date[i+1]
    y = train.loc[train['date'] == d_next].return_list.iloc[0].loc[d_next].reset_index()
    y.columns = ['tic', 'return']
    x = train.loc[train['date'] == d][['tic', 'macd', 'rsi_30', 'boll_lb', 'dx_30']] # cci_30
    train_piece = pd.merge(x, y, on = 'tic')
    train_piece['date'] = [d] * len(train_piece)
    X += [train_piece]
  trainDataML = pd.concat(X)
  X = trainDataML[['macd', 'rsi_30', 'boll_lb', 'dx_30']].values # cci_30
  Y = trainDataML[['return']].values

  return X, Y

train_X, train_Y = prepare_data(train)
rf_model = RandomForestRegressor(max_depth = 35,  min_samples_split = 10, random_state = 0).fit(train_X, train_Y.reshape(-1))
dt_model = DecisionTreeRegressor(random_state = 0, max_depth=35, min_samples_split = 10 ).fit(train_X, train_Y.reshape(-1))
svm_model =  SVR(epsilon=0.14).fit(train_X, train_Y.reshape(-1))
lr_model = LinearRegression().fit(train_X, train_Y)

# %%
def output_predict(model, reference_model = False):
  meta_coefficient = {"date":[], "weights":[]}

  portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
  initial_capital = 1000000
  portfolio.loc[0,unique_trade_date[0]] = initial_capital

  for i in range(len(unique_trade_date) - 1):
      
      current_date = unique_trade_date[i]
      next_date = unique_trade_date[i+1]
      df_current = df[df.date==current_date].reset_index(drop=True)
      tics = df_current['tic'].values
      features = df_current[['macd', 'rsi_30', 'boll_lb', 'dx_30']].values # cci_30
      df_next = df[df.date==next_date].reset_index(drop=True)
      if not reference_model:
        predicted_y = model.predict(features)      
        mu = predicted_y
        Sigma = risk_models.sample_cov(df_current.return_list[0], returns_data=True)
      else:
        mu = df_next.return_list[0].loc[next_date].values
        Sigma = risk_models.sample_cov(df_next.return_list[0], returns_data=True)
      predicted_y_df = pd.DataFrame({"tic":tics.reshape(-1,), "predicted_y":mu.reshape(-1,)})
      min_weight, max_weight = 0, 1
      ef = EfficientFrontier(mu, Sigma)
      weights = ef.nonconvex_objective(
          objective_functions.sharpe_ratio,
          objective_args=(ef.expected_returns, ef.cov_matrix),
          weights_sum_to_one=True,
          constraints=[
              {"type": "ineq", "fun": lambda w: w - min_weight},  # greater than min_weight
              {"type": "ineq", "fun": lambda w: max_weight - w},  # less than max_weight
          ],
      )
      
      weight_df = {"tic":[], "weight":[]}
      meta_coefficient["date"] += [current_date]
      # it = 0
      for item in weights:
        weight_df['tic'] += [item]
        weight_df['weight'] += [weights[item]]
      
      weight_df = pd.DataFrame(weight_df).merge(predicted_y_df, on = ['tic'])
      meta_coefficient["weights"] += [weight_df]
      cap = portfolio.iloc[0, i]
      #current cash invested for each stock
      current_cash = [element * cap for element in list(weights.values())]
      # current held shares
      current_shares = list(np.array(current_cash) / np.array(df_current.close))
      # next time period price
      next_price = np.array(df_next.close)
      portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)
      
  portfolio=portfolio.T
  portfolio.columns = ['account_value']
  portfolio = portfolio.reset_index()
  portfolio.columns = ['date', 'account_value']
  stats = backtest_stats(portfolio, value_col_name = 'account_value')
  portfolio_cumprod =(portfolio.account_value.pct_change()+1).cumprod()-1

  return portfolio, stats, portfolio_cumprod, pd.DataFrame(meta_coefficient)

lr_portfolio, lr_stats, lr_cumprod, lr_weights = output_predict(lr_model)
dt_portfolio, dt_stats, dt_cumprod, dt_weights = output_predict(dt_model)
svm_portfolio, svm_stats, svm_cumprod, svm_weights = output_predict(svm_model)
rf_portfolio, rf_stats, rf_cumprod, rf_weights = output_predict(rf_model)
reference_portfolio, reference_stats, reference_cumprod, reference_weights = output_predict(None, True)
# Out:
# Annual return          0.271340
# Cumulative returns     0.260486
# Annual volatility      0.503625
# Sharpe ratio           0.727868
# Calmar ratio           0.809913
# Stability              0.589350
# Max drawdown          -0.335023
# Omega ratio            1.130555
# Sortino ratio          1.132339
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.267527
# Daily value at risk   -0.061996
# dtype: float64
# Annual return          0.050831
# Cumulative returns     0.048972
# Annual volatility      0.446848
# Sharpe ratio           0.331659
# Calmar ratio           0.128330
# Stability              0.193206
# Max drawdown          -0.396094
# Omega ratio            1.060655
# Sortino ratio          0.514943
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.059516
# Daily value at risk   -0.055709
# dtype: float64
# Annual return          0.027183
# Cumulative returns     0.026199
# Annual volatility      0.527386
# Sharpe ratio           0.311786
# Calmar ratio           0.064805
# Stability              0.044615
# Max drawdown          -0.419454
# Omega ratio            1.055204
# Sortino ratio          0.474070
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.132725
# Daily value at risk   -0.065792
# dtype: float64
# Annual return          0.871872
# Cumulative returns     0.830426
# Annual volatility      0.518390
# Sharpe ratio           1.470012
# Calmar ratio           2.750810
# Stability              0.749022
# Max drawdown          -0.316951
# Omega ratio            1.280943
# Sortino ratio          2.507061
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.694656
# Daily value at risk   -0.062287
# dtype: float64
# Annual return          1.123149e+05
# Cumulative returns     7.414169e+04
# Annual volatility      4.780386e-01
# Sharpe ratio           2.522783e+01
# Calmar ratio           3.685333e+06
# Stability              9.973045e-01
# Max drawdown          -3.047619e-02
# Omega ratio            1.078144e+02
# Sortino ratio          2.261533e+02
# Skew                            NaN
# Kurtosis                        NaN
# Tail ratio             1.178658e+01
# Daily value at risk   -1.237055e-02
# dtype: float64

# %% [markdown]
# # Part 7: Explanation Method Implementation

# %% [markdown]
# ### Integrated Gradient
# Implement the explanation method using integrated gradients and regression coefficients.

# %%
meta_Q = {"date":[], "feature":[], "Saliency Map":[], "algo":[]}
for algo in {"A2C", "PPO"}:
    model = eval("trained_" + algo.lower())
    df_actions = eval("df_actions_" + algo.lower())
    for i in range(len(unique_trade_date)-1):
        date = unique_trade_date[i]
        covs = trade[trade['date'] == date].cov_list.iloc[0]
        features = trade[trade['date'] == date][['macd','rsi_30', 'boll_lb', 'dx_30']].values # cci_30
        input = np.append(covs, features.T, axis = 0)
        actions = df_actions.loc[date].values
        orig_Q = model.policy.evaluate_actions(torch.cuda.FloatTensor(input).reshape(-1,stock_dimension*(stock_dimension + 4)), torch.cuda.FloatTensor(actions).reshape(-1, stock_dimension))
        orig_Q = orig_Q[0].detach().cpu().numpy()[0]
        for idx in range(len(['macd','rsi_30', 'boll_lb', 'dx_30'])): # cci_30
            perturbed_feature = features
            perturbed_noise = np.random.normal(0, 1, stock_dimension)
            perturbed_feature[:,idx] = [0] * stock_dimension
            perturbed_input = np.append(covs, perturbed_feature.T, axis = 0)
            perturbed_Q = model.policy.evaluate_actions(torch.cuda.FloatTensor(perturbed_input).reshape(-1,stock_dimension*(stock_dimension + 4)), torch.cuda.FloatTensor(actions).reshape(-1,stock_dimension))
            perturbed_Q = perturbed_Q[0].detach().cpu().numpy()[0]
            meta_Q['date'] += [date]
            meta_Q['algo'] += [algo]
            meta_Q['feature'] += [['macd','rsi_30', 'boll_lb', 'dx_30'][idx]] # cci_30
            meta_Q['Saliency Map'] += [orig_Q[0] - perturbed_Q[0]]

meta_Q = pd.DataFrame(meta_Q)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-51-320f71a4cff2> in <module>
#       9         input = np.append(covs, features.T, axis = 0)
#      10         actions = df_actions.loc[date].values
# ---> 11         orig_Q = model.policy.evaluate_actions(torch.cuda.FloatTensor(input).reshape(-1,stock_dimension*(stock_dimension + 4)), torch.cuda.FloatTensor(actions).reshape(-1, stock_dimension))
#      12         orig_Q = orig_Q[0].detach().cpu().numpy()[0]
#      13         for idx in range(len(['macd','rsi_30', 'boll_lb', 'dx_30'])): # cci_30
#
# d:\code\python\stable-baselines3\stable_baselines3\common\policies.py in evaluate_actions(self, obs, actions)
#     642         # Preprocess the observation if needed
#     643         features = self.extract_features(obs)
# --> 644         latent_pi, latent_vf = self.mlp_extractor(features)
#     645         distribution = self._get_action_dist_from_latent(latent_pi)
#     646         log_prob = distribution.log_prob(actions)
#
# d:\soft\python\python37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# d:\code\python\stable-baselines3\stable_baselines3\common\torch_layers.py in forward(self, features)
#     226         """
#     227         shared_latent = self.shared_net(features)
# --> 228         return self.policy_net(shared_latent), self.value_net(shared_latent)
#     229
#     230     def forward_actor(self, features: th.Tensor) -> th.Tensor:
#
# d:\soft\python\python37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# d:\soft\python\python37\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# d:\soft\python\python37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# d:\soft\python\python37\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# d:\soft\python\python37\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# RuntimeError: mat1 dim 1 must match mat2 dim 0

# %% [markdown]
# ### Regression Coefficient
# Implement the linear regression to measure the feature weights.

# %%
import statsmodels.api as sm
meta_score_coef = {"date":[], "coef":[], "algo":[]}

for algo in ["LR", "RF", "Reference Model", "SVM", "DT", "A2C", "PPO"]:
  if algo == "LR":
    weights = lr_weights
  elif algo == "RF":
    weights = rf_weights
  elif algo == "DT":
    weights = dt_weights
  elif algo == "SVM":
    weights = svm_weights
  elif algo == "A2C":
    weights = a2c_weights
  elif algo == "PPO":
    weights = ppo_weights
  else:
    weights = reference_weights

  for i in range(len(unique_trade_date) - 1):
    date = unique_trade_date[i]
    next_date = unique_trade_date[i+1]
    df_temp = df[df.date==date].reset_index(drop=True)
    df_temp_next = df[df.date==next_date].reset_index(drop=True)
    weight_piece = weights[weights.date == date].iloc[0]['weights']
    piece_return = pd.DataFrame(df_temp_next.return_list.iloc[0].loc[next_date]).reset_index()
    piece_return.columns = ['tic', 'return']
    X = df_temp[['macd','rsi_30', 'boll_lb', 'dx_30', 'tic']] # cci_30
    X_next = df_temp_next[['macd','rsi_30', 'boll_lb', 'dx_30', 'tic']] # cci_30
    piece = weight_piece.merge(X, on = 'tic').merge(piece_return, on = 'tic')
    piece['Y'] = piece['return'] * piece['weight']
    X = piece[['macd','rsi_30', 'boll_lb', 'dx_30']] # cci_30
    X = sm.add_constant(X)
    Y = piece[['Y']]
    model = sm.OLS(Y,X)
    results = model.fit()
    meta_score_coef["coef"] += [(X * results.params).sum(axis = 0)]
    meta_score_coef["date"] += [date]
    meta_score_coef["algo"] += [algo]

meta_score_coef = pd.DataFrame(meta_score_coef)
# Out:
# d:\soft\python\python37\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# ### Correlation Coefficient
# Calculate the  sing-step and multi-step correlation coefficients

# %%
performance_score = {"date":[], "algo":[], "score":[]}

for i in range(0, len(unique_trade_date)):
  date_ = unique_trade_date[i]
  if len(meta_score_coef[(meta_score_coef['date'] == date_)]) == 0:
    continue 
  lr_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'LR')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  rf_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'RF')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  reference_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'Reference Model')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  dt_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'DT')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  svm_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'SVM')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30

  saliency_coef_a2c = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "A2C")]['Saliency Map'].values
  saliency_coef_ppo = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "PPO")]['Saliency Map'].values

  lr_score = np.corrcoef(lr_coef, reference_coef)[0][1]
  rf_score = np.corrcoef(rf_coef, reference_coef)[0][1]
  dt_score = np.corrcoef(dt_coef, reference_coef)[0][1]
  svm_score = np.corrcoef(svm_coef, reference_coef)[0][1]
  saliency_score_a2c = np.corrcoef(saliency_coef_a2c, reference_coef)[0][1]
  saliency_score_ppo = np.corrcoef(saliency_coef_ppo, reference_coef)[0][1]

  for algo in ["LR","A2C","PPO","RF","DT", "SVM"]:
    performance_score["date"] += [date_]
    performance_score["algo"] += [algo]
    if algo == "LR":
      score = lr_score 
    elif algo == "RF":
      score = rf_score
    elif algo == "DT":
      score = dt_score
    elif algo == "A2C":
      score = saliency_score_a2c
    elif algo == "SVM":
      score = svm_score
    else:
      score = saliency_score_ppo
    performance_score["score"] += [score]

performance_score = pd.DataFrame(performance_score)
# Out:
# d:\soft\python\python37\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   del sys.path[0]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-5be2ce9b9c06> in <module>
#      11   svm_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'SVM')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
#      12
# ---> 13   saliency_coef_a2c = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "A2C")]['Saliency Map'].values
#      14   saliency_coef_ppo = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "PPO")]['Saliency Map'].values
#      15
#
# KeyError: False

# %%
multi_performance_score = {"date":[], "algo":[], "score":[]}
window = 15
for i in range(len(unique_trade_date) - window ):
  date_ = unique_trade_date[i]
  if len(meta_score_coef[(meta_score_coef['date'] == date_)]) == 0:
    continue 
  lr_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'LR')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  rf_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'RF')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  reference_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'Reference Model')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  for w in range(1, window):
      date_f = unique_trade_date[i + w]
      prx_coef = meta_score_coef[(meta_score_coef['date'] == date_f) & (meta_score_coef['algo'] == 'Reference Model')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
      reference_coef += prx_coef
  reference_coef = reference_coef / window
  dt_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'DT')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  svm_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'SVM')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
  saliency_coef_a2c = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "A2C")]['Saliency Map'].values
  saliency_coef_ppo = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "PPO")]['Saliency Map'].values
  lr_score = np.corrcoef(lr_coef, reference_coef)[0][1]
  rf_score = np.corrcoef(rf_coef, reference_coef)[0][1]
  dt_score = np.corrcoef(dt_coef, reference_coef)[0][1]
  svm_score = np.corrcoef(svm_coef, reference_coef)[0][1]
  saliency_score_a2c = np.corrcoef(saliency_coef_a2c, reference_coef)[0][1]
  saliency_score_ppo = np.corrcoef(saliency_coef_ppo, reference_coef)[0][1]

  for algo in ["LR", "A2C", "RF", "PPO", "DT", "SVM"]:
    multi_performance_score["date"] += [date_]
    multi_performance_score["algo"] += [algo]
    if algo == "LR":
      score = lr_score 
    elif algo == "RF":
      score = rf_score
    elif algo == "DT":
      score = dt_score
    elif algo == "A2C":
      score = saliency_score_a2c
    elif algo == "SVM":
      score = svm_score
    else:
      score = saliency_score_ppo
    multi_performance_score["score"] += [score]

multi_performance_score = pd.DataFrame(multi_performance_score)
# Out:
# d:\soft\python\python37\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-b5c8020d2ba0> in <module>
#      15   dt_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'DT')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
#      16   svm_coef = meta_score_coef[(meta_score_coef['date'] == date_) & (meta_score_coef['algo'] == 'SVM')]['coef'].values[0][['macd','rsi_30','boll_lb','dx_30']].values # cci_30
# ---> 17   saliency_coef_a2c = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "A2C")]['Saliency Map'].values
#      18   saliency_coef_ppo = meta_Q[(meta_Q['date'] == date_) & (meta_Q['algo'] == "PPO")]['Saliency Map'].values
#      19   lr_score = np.corrcoef(lr_coef, reference_coef)[0][1]
#
# KeyError: False

# %% [markdown]
# ### Data Visualization

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
trace1_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C')
trace2_portfolio = go.Scatter(x = time_ind, y = ppo_cumpod, mode = 'lines', name = 'PPO')
trace3_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace4_portfolio = go.Scatter(x = time_ind, y = lr_cumprod, mode = 'lines', name = 'LR')
trace5_portfolio = go.Scatter(x = time_ind, y = rf_cumprod, mode = 'lines', name = 'RF')
trace6_portfolio = go.Scatter(x = time_ind, y = dt_cumprod, mode = 'lines', name = 'DT')
trace7_portfolio = go.Scatter(x = time_ind, y = svm_cumprod, mode = 'lines', name = 'SVM')

# %%
fig = go.Figure()
fig.add_trace(trace1_portfolio)
fig.add_trace(trace2_portfolio)

fig.add_trace(trace3_portfolio)

fig.add_trace(trace4_portfolio)
fig.add_trace(trace5_portfolio)
fig.add_trace(trace6_portfolio)
fig.add_trace(trace7_portfolio)

fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2
        
    ),
)
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.update_layout(
    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    xaxis_title="Date",
    yaxis = dict(titlefont = dict(size = 30), title = "Cumulative Return"),
    font=dict(
        size=40,
    ),
)
fig.update_layout(font_size = 20)
fig.update_traces(line=dict(width=2))

fig.update_xaxes(showline=True, linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show("png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-ff387ee06f6d> in <module>
#      49 fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')
#      50
# ---> 51 fig.show("png")
#
# d:\soft\python\python37\lib\site-packages\plotly\basedatatypes.py in show(self, *args, **kwargs)
#    3396         import plotly.io as pio
#    3397
# -> 3398         return pio.show(self, *args, **kwargs)
#    3399
#    3400     def to_json(self, *args, **kwargs):
#
# d:\soft\python\python37\lib\site-packages\plotly\io\_renderers.py in show(fig, renderer, validate, **kwargs)
#     387
#     388     # Mimetype renderers
# --> 389     bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     390     if bundle:
#     391         if not ipython_display:
#
# d:\soft\python\python37\lib\site-packages\plotly\io\_renderers.py in _build_mime_bundle(self, fig_dict, renderers_string, **kwargs)
#     295                         setattr(renderer, k, v)
#     296
# --> 297                 bundle.update(renderer.to_mimebundle(fig_dict))
#     298
#     299         return bundle
#
# d:\soft\python\python37\lib\site-packages\plotly\io\_base_renderers.py in to_mimebundle(self, fig_dict)
#     133             scale=self.scale,
#     134             validate=False,
# --> 135             engine=self.engine,
#     136         )
#     137
#
# d:\soft\python\python37\lib\site-packages\plotly\io\_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     137 which can be installed using pip:
#     138     $ pip install -U kaleido
# --> 139 """
#     140         )
#     141
#
# ValueError:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido

# %% [markdown]
# #### We found that A2C and PPO succeeded in the portfoli management task and is better than all other algorithms/benchmark.

# %%
meta_score = {"Annual return":[], "Annual volatility":[], "Max drawdown":[], "Sharpe ratio":[], "Algorithm":[], "Calmar ratio":[]}
for name in ["LR", "A2C", "RF", "Reference Model", "PPO", "SVM", "DT", "DJI"]:
  if name == "DT":
    annualreturn = dt_stats["Annual return"]
    annualvol = dt_stats["Annual volatility"]
    sharpeRatio = dt_stats["Sharpe ratio"]
    maxdradown = dt_stats["Max drawdown"]
    calmarratio = dt_stats["Calmar ratio"]
  elif name == "LR":
    annualreturn = lr_stats["Annual return"]
    annualvol = lr_stats["Annual volatility"]
    sharpeRatio = lr_stats["Sharpe ratio"]
    maxdradown = lr_stats["Max drawdown"]
    calmarratio = lr_stats["Calmar ratio"]
  elif name == "SVM":
    annualreturn = svm_stats["Annual return"]
    annualvol = svm_stats["Annual volatility"]
    sharpeRatio = svm_stats["Sharpe ratio"]
    maxdradown = svm_stats["Max drawdown"]
    calmarratio = svm_stats["Calmar ratio"]
  elif name == "RF":
    annualreturn = rf_stats["Annual return"]
    annualvol = rf_stats["Annual volatility"]
    sharpeRatio = rf_stats["Sharpe ratio"]
    maxdradown = rf_stats["Max drawdown"]
    calmarratio = rf_stats["Calmar ratio"]
  elif name == "Reference Model":
    annualreturn = reference_stats["Annual return"]
    annualvol = reference_stats["Annual volatility"]
    sharpeRatio = reference_stats["Sharpe ratio"]
    maxdradown = reference_stats["Max drawdown"]
    calmarratio = reference_stats["Calmar ratio"]
  elif name == "PPO":
    annualreturn = perf_stats_all_ppo["Annual return"]
    annualvol = perf_stats_all_ppo["Annual volatility"]
    sharpeRatio = perf_stats_all_ppo["Sharpe ratio"]
    maxdradown = perf_stats_all_ppo["Max drawdown"]
    calmarratio = perf_stats_all_ppo["Calmar ratio"]
  elif name == "DJI":
    annualreturn = baseline_df_stats["Annual return"]
    annualvol = baseline_df_stats["Annual volatility"]
    sharpeRatio = baseline_df_stats["Sharpe ratio"]
    maxdradown = baseline_df_stats["Max drawdown"]
    calmarratio = baseline_df_stats["Calmar ratio"]
  else:
    annualreturn = perf_stats_all_a2c["Annual return"]
    annualvol = perf_stats_all_a2c["Annual volatility"]
    sharpeRatio = perf_stats_all_a2c["Sharpe ratio"]
    maxdradown = perf_stats_all_a2c["Max drawdown"]
    calmarratio = perf_stats_all_a2c["Calmar ratio"]
  meta_score["Algorithm"] += [name]
  meta_score["Annual return"] += [annualreturn]
  meta_score["Annual volatility"] += [annualvol]
  meta_score["Max drawdown"] += [maxdradown]
  meta_score["Sharpe ratio"] += [sharpeRatio]
  meta_score["Calmar ratio"] += [calmarratio]

meta_score = pd.DataFrame(meta_score).sort_values("Sharpe ratio")

# %%
postiveRatio = pd.DataFrame(performance_score.groupby("algo").apply(lambda x : np.mean(x['score'])))

postiveRatio = postiveRatio.reset_index()
postiveRatio.columns = ['algo', 'avg_correlation_coefficient']
postiveRatio['Sharpe Ratio'] = [0] * 6

# postiveRatio.plot.bar(x = 'algo', y = 'avg_correlation_coefficient')

postiveRatiom = pd.DataFrame(multi_performance_score.groupby("algo").apply(lambda x : np.mean(x['score'])))
postiveRatiom = postiveRatiom.reset_index()
postiveRatiom.columns = ['algo', 'avg_correlation_coefficient']
postiveRatiom['Sharpe Ratio'] = [0] * 6

# postiveRatiom.plot.bar(x = 'algo', y = 'avg_correlation_coefficient')


for algo in ['A2C', 'PPO', 'LR','DT', 'RF', 'SVM']:
  postiveRatio.loc[postiveRatio['algo'] == algo, 'Sharpe Ratio'] = meta_score.loc[meta_score['Algorithm'] == algo,'Sharpe ratio'].values[0]
  postiveRatiom.loc[postiveRatio['algo'] == algo, 'Sharpe Ratio'] = meta_score.loc[meta_score['Algorithm'] == algo,'Sharpe ratio'].values[0]

postiveRatio.sort_values("Sharpe Ratio", inplace= True)

postiveRatiom.sort_values("Sharpe Ratio", inplace= True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-71d59f036790> in <module>
# ----> 1 postiveRatio = pd.DataFrame(performance_score.groupby("algo").apply(lambda x : np.mean(x['score'])))
#       2
#       3 postiveRatio = postiveRatio.reset_index()
#       4 postiveRatio.columns = ['algo', 'avg_correlation_coefficient']
#       5 postiveRatio['Sharpe Ratio'] = [0] * 6
#
# AttributeError: 'dict' object has no attribute 'groupby'

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(x=postiveRatiom['algo'], y=postiveRatiom['Sharpe Ratio'], name="Sharpe Ratio", marker_size = 15, line_width=5),
    secondary_y=True,
)

fig.add_trace(
    go.Bar(x=postiveRatiom['algo'], y=postiveRatiom['avg_correlation_coefficient'], name="Multi-Step Average Correlation Coefficient          ", width
    =0.38),
    secondary_y=False,
)
fig.add_trace(
    go.Bar(x=postiveRatio['algo'], y=postiveRatio['avg_correlation_coefficient'], name="Single-Step Average Correlation Coefficient           ", width
    =0.38),
    secondary_y=False,
)
    
fig.update_layout(
    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
)
fig.update_layout(legend=dict(
    yanchor="top",
    y=1.5,
    xanchor="right",
    x=0.95
))
fig.update_layout(font_size = 15)

# Set x-axis title
fig.update_xaxes(title_text="Model")
fig.update_xaxes(showline=True, linecolor='black',showgrid=True,gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, secondary_y=False, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')
# Set y-axes titles
fig.update_yaxes(title_text="Average Correlation Coefficient", secondary_y=False, range = [-0.1,0.1])
fig.update_yaxes(title_text="Sharpe Ratio", secondary_y=True,range = [-0.5,2.5])

fig.show("png")

# %% [markdown]
# #### The correlation coefficient represents the level of prediction power.
#
# We found that:
# >*  The sharpe ratio is in accordance with both single-step and  multi-step average correlation coefficient.
# >* DRL agents is better at multi-step prediction than ML algorithms while worse at single-step prediction

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots


fig = make_subplots(rows=2, cols=3)

trace0 = go.Histogram(x=performance_score[performance_score['algo'] == 'A2C']['score'].values, nbinsx=25, name = 'A2C',histnorm='probability')
trace1 = go.Histogram(x=performance_score[performance_score['algo'] == 'PPO']['score'].values, nbinsx=25, name = 'PPO',histnorm='probability')
trace2 = go.Histogram(x=performance_score[performance_score['algo'] == 'DT']['score'].values, nbinsx=25, name = 'DT',histnorm='probability')
trace3 = go.Histogram(x=performance_score[performance_score['algo'] == 'LR']['score'].values, nbinsx=25, name = 'LR',histnorm='probability')
trace4 = go.Histogram(x=performance_score[performance_score['algo'] == 'SVM']['score'].values, nbinsx=25, name = 'SVM',histnorm='probability')
trace5 = go.Histogram(x=performance_score[performance_score['algo'] == 'RF']['score'].values, nbinsx=25, name = 'RF',histnorm='probability')


fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 2)
fig.append_trace(trace2, 1, 3)
fig.append_trace(trace3, 2, 1)
fig.append_trace(trace4, 2, 2)
fig.append_trace(trace5, 2, 3)
# Update xaxis properties
fig.update_xaxes(title_text="Correlation coefficient", row=2, col=2)
fig.update_yaxes(title_text="Frequency", row=1, col=1)
fig.update_yaxes(title_text="Frequency", row=2, col=1)

fig.update_layout(

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
     font=dict(
       
        size=18,
    ),

)
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=1
))

fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show("png")

# %% [markdown]
# #### Histogram of single-step correlation coefficient

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots


fig = make_subplots(rows=2, cols=3)

trace0 = go.Histogram(x=multi_performance_score[multi_performance_score['algo'] == 'A2C']['score'].values, nbinsx=25, name = 'A2C',histnorm='probability')
trace1 = go.Histogram(x=multi_performance_score[multi_performance_score['algo'] == 'PPO']['score'].values, nbinsx=25, name = 'PPO',histnorm='probability')
trace2 = go.Histogram(x=multi_performance_score[multi_performance_score['algo'] == 'DT']['score'].values, nbinsx=25, name = 'DT',histnorm='probability')
trace3 = go.Histogram(x=multi_performance_score[multi_performance_score['algo'] == 'LR']['score'].values, nbinsx=25, name = 'LR',histnorm='probability')
trace4 = go.Histogram(x=multi_performance_score[multi_performance_score['algo'] == 'SVM']['score'].values, nbinsx=25, name = 'SVM',histnorm='probability')
trace5 = go.Histogram(x=multi_performance_score[multi_performance_score['algo'] == 'RF']['score'].values, nbinsx=25, name = 'RF',histnorm='probability')

fig.update_layout(yaxis1 = dict(range=[0, 0.2]))
fig.update_layout(yaxis2 = dict(range=[0, 0.2]))
fig.update_layout(yaxis3 = dict(range=[0, 0.4]))
fig.update_layout(yaxis4 = dict(range=[0, 0.4]))
fig.update_layout(yaxis5 = dict(range=[0, 0.4]))
fig.update_layout(yaxis6 = dict(range=[0, 0.4]))

fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 2)
fig.append_trace(trace2, 1, 3)
fig.append_trace(trace3, 2, 1)
fig.append_trace(trace4, 2, 2)
fig.append_trace(trace5, 2, 3)
# Update xaxis properties
fig.update_xaxes(title_text="Correlation coefficient", row=2, col=2)
fig.update_yaxes(title_text="Frequency", row=1, col=1)
fig.update_yaxes(title_text="Frequency", row=2, col=1)

fig.update_layout(

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
     font=dict(
       
        size=18,
    ),

)
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=1
))

fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show("png")

# %% [markdown]
# #### Histogram of multi-step correlation coefficient
