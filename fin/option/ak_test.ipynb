# %% [markdown]
# ### https://www.akshare.xyz/data/option/option.html

# %%
import akshare as ak

# %%
option_finance_board_df = ak.option_finance_board(symbol='华夏上证50ETF期权', end_month="2303")

# %%
option_finance_board_df
# Out:
#                 日期             合约交易代码     当前价    涨跌幅     前结价    行权价  数量
# 0   20230209134734  510050C2303A02650  0.1767  13.34  0.1559  2.613  66
# 1   20230209134734  510050C2303A02700  0.1404  17.59  0.1194  2.662  66
# 2   20230209134734  510050C2303A02750  0.1044  17.97  0.0885  2.711  66
# 3   20230209134734  510050C2303A02800  0.0754  18.93  0.0634  2.761  66
# 4   20230209134734  510050C2303A02850  0.0531  22.07  0.0435  2.810  66
# ..             ...                ...     ...    ...     ...    ...  ..
# 61  20230209134734  510050P2303M02950  0.1908 -11.50  0.2156  2.950  66
# 62  20230209134734  510050C2303M03000  0.0123  24.24  0.0099  3.000  66
# 63  20230209134734  510050P2303M03000  0.2345  -9.91  0.2603  3.000  66
# 64  20230209134734  510050C2303M03100  0.0060  15.38  0.0052  3.100  66
# 65  20230209134734  510050P2303M03100  0.3302  -8.28  0.3600  3.100  66
#
# [66 rows x 7 columns]

# %%
option_finance_board_df = ak.option_finance_board(symbol="嘉实沪深300ETF期权", end_month="2303")

# %%
option_finance_board_df
# Out:
#          合约编码             合约简称      标的名称  类型    行权价   合约单位      期权行权日  \
# 0    90001173  沪深300ETF购3月3900  沪深300ETF  认购  3.900  10000 2023-03-22
# 1    90001174  沪深300ETF购3月4000  沪深300ETF  认购  4.000  10000 2023-03-22
# 2    90001175  沪深300ETF购3月4100  沪深300ETF  认购  4.100  10000 2023-03-22
# 3    90001176  沪深300ETF购3月4200  沪深300ETF  认购  4.200  10000 2023-03-22
# 4    90001177  沪深300ETF购3月4300  沪深300ETF  认购  4.300  10000 2023-03-22
# ..        ...              ...       ...  ..    ...    ...        ...
# 111  90001798    创业板ETF沽3月2700    创业板ETF  认沽  2.700  10000 2023-03-22
# 112  90001811  中证500ETF购3月7500  中证500ETF  认购  7.500  10000 2023-03-22
# 113  90001812  中证500ETF沽3月7500  中证500ETF  认沽  7.500  10000 2023-03-22
# 114  90001889    创业板ETF购3月2750    创业板ETF  认购  2.750  10000 2023-03-22
# 115  90001890    创业板ETF沽3月2750    创业板ETF  认沽  2.750  10000 2023-03-22
#
#           行权交收日
# 0    2023-03-23
# 1    2023-03-23
# 2    2023-03-23
# 3    2023-03-23
# 4    2023-03-23
# ..          ...
# ...

# %%
option_finance_board_df = ak.option_finance_board(symbol="沪深300股指期权", end_month="2303")

# %%
option_finance_board_df
# Out:
#         instrument  position  volume  lastprice  updown  bprice  bamount  \
# 54   IO2303-C-3100        53       3      984.0     1.0   991.4        9
# 55   IO2303-C-3200       113       1      899.4    16.0   892.2        6
# 56   IO2303-C-3300        78       2      802.2    18.2   792.4       12
# 57   IO2303-C-3400       234       4      684.0    -0.6   695.0        4
# 58   IO2303-C-3450         6       2      649.6    14.4   645.4        1
# ..             ...       ...     ...        ...     ...     ...      ...
# 115  IO2303-P-4650         5       2      552.2   -16.4   552.8        9
# 116  IO2303-P-4700       161       2      601.2   -16.6   602.4        3
# 117  IO2303-P-4800       166       2      712.8    -4.2   701.2        6
# 118  IO2303-P-4900       131       2      813.8    -2.6   800.4        1
# 119  IO2303-P-5000       341       3      901.4   -14.8   900.0        1
#
#      sprice  samount
# 54    998.2       12
# 55    898.0        6
# 56    798.0        6
# ...

# %%
option_risk_indicator_sse_df = ak.option_risk_indicator_sse(date='20230206') # 20220516

# %%
option_risk_indicator_sse_df
# Out:
#      TRADE_DATE SECURITY_ID        CONTRACT_ID CONTRACT_SYMBOL  DELTA_VALUE  \
# 0    2023-02-06    10004939  510050C2302M02450    50ETF购2月2450        0.983
# 1    2023-02-06    10004940  510050C2302M02500    50ETF购2月2500        1.000
# 2    2023-02-06    10004941  510050C2302M02550    50ETF购2月2550        0.949
# 3    2023-02-06    10004942  510050C2302M02600    50ETF购2月2600        0.897
# 4    2023-02-06    10004943  510050C2302M02650    50ETF购2月2650        0.800
# ..          ...         ...                ...             ...          ...
# 417  2023-02-06    10005155  510500P2309M06500   500ETF沽9月6500       -0.486
# 418  2023-02-06    10005156  510500P2309M06750   500ETF沽9月6750       -0.570
# 419  2023-02-06    10005157  510500P2309M07000   500ETF沽9月7000       -0.640
# 420  2023-02-06    10005158  510500P2309M07250   500ETF沽9月7250       -0.694
# 421  2023-02-06    10005168  510500P2309M07500   500ETF沽9月7500       -0.735
#
# ...

# %%
option_cffex_sz50_list_sina_df = ak.option_cffex_sz50_list_sina()

# %%
option_cffex_sz50_list_sina_df
# Out:
# {'上证50指数': ['ho2302', 'ho2303', 'ho2309', 'ho2306', 'ho2304', 'ho2312']}

# %%
option_cffex_hs300_list_sina_df = ak.option_cffex_hs300_list_sina()

# %%
option_cffex_hs300_list_sina_df
# Out:
# {'上证50指数': ['io2302', 'io2303', 'io2309', 'io2306', 'io2312', 'io2304']}

# %%
option_cffex_hs300_spot_sina_df = ak.option_cffex_hs300_spot_sina(symbol="io2303")

# %%
option_cffex_hs300_spot_sina_df
# Out:
#     看涨合约-买量  看涨合约-买价  看涨合约-最新价  看涨合约-卖价  看涨合约-卖量  看涨合约-持仓量  看涨合约-涨跌   行权价  \
# 0         1    971.8    1000.0   1000.2        1        51     0.66  3100
# 1         1    884.0     899.4    913.4        1       113     1.81  3200
# 2         1    784.4     802.2    813.8        1        78     2.32  3300
# 3         1    746.6     720.8    750.6        6       232     4.95  3400
# 4         1    635.6     649.6    662.8        1         6     2.27  3450
# 5         1    647.2     620.8    650.6        9       194     5.61  3500
# 6         1    536.8     543.6    561.6        1        15     1.46  3550
# 7        12    546.6     544.6    551.0        6       163    11.28  3600
# 8        12    497.8     494.6    501.8        9        19    12.26  3650
# 9         1    450.0     444.8    453.2        9       177    13.35  3700
# 10        1    401.6     378.4    404.2        3        18     9.74  3750
# 11        6    352.2     351.8    356.0        6       394    19.09  3800
# ...

# %%
option_cffex_hs300_daily_sina_df = ak.option_cffex_hs300_daily_sina(symbol="io2303C3100")

# %%
option_cffex_hs300_daily_sina_df
# Out:
#           date    open    high     low   close  volume
# 0   2022-10-31   464.8   483.0   453.8   462.8      14
# 1   2022-11-01   487.4   525.2   487.0   525.2      10
# 2   2022-11-02   610.4   613.8   606.0   609.8       9
# 3   2022-11-03   588.0   588.0   585.0   585.0       2
# 4   2022-11-04   711.8   711.8   703.0   703.0      10
# 5   2022-11-07   680.0   682.0   680.0   682.0      18
# 6   2022-11-08   681.0   681.0   676.4   676.4       3
# 7   2022-11-09   664.2   664.2   640.0   640.0       4
# 8   2022-11-10   615.0   616.0   615.0   616.0       3
# 9   2022-11-11   760.0   788.2   687.8   735.0       6
# 10  2022-11-14   753.0   753.0   719.8   719.8       3
# 11  2022-11-15   784.8   784.8   784.8   784.8       1
# 12  2022-11-16   772.2   772.2   769.2   769.2       7
# 13  2022-11-21   690.0   690.0   690.0   690.0       2
# 14  2022-11-22   686.2   696.0   683.6   696.0       4
# 15  2022-11-25   714.8   714.8   714.8   714.8       1
# ...

# %%
option_sse_codes_sina_df = ak.option_sse_codes_sina(trade_date='202302', underlying='510050')

# %%
option_sse_codes_sina_df
# Out:
#     序号      期权代码
# 0    1  10004939
# 1    2  10004940
# 2    3  10004941
# 3    4  10004942
# 4    5  10004943
# 5    6  10004944
# 6    7  10004945
# 7    8  10004946
# 8    9  10004947
# 9   10  10004995
# 10  11  10004999
# 11  12  10005009
# 12  13  10005089

# %%
option_sse_minute_sina_df = ak.option_sse_minute_sina(symbol="10004929")

# %%
option_sse_minute_sina_df
# Out:
#              日期        时间      价格  成交     持仓      均价
# 0    2023-02-07  09:26:00  0.0262   0      0  0.0262
# 1    2023-02-07  09:27:00  0.0262   0      0  0.0262
# 2    2023-02-07  09:28:00  0.0262   0      0  0.0262
# 3    2023-02-07  09:29:00  0.0262   0      0  0.0262
# 4    2023-02-07  09:30:00  0.0279  91  23098  0.0278
# ..          ...       ...     ...  ..    ...     ...
# 330  2023-02-07  14:56:00  0.0253   1  24130  0.0256
# 331  2023-02-07  14:57:00  0.0253   0  24151  0.0256
# 332  2023-02-07  14:58:00  0.0253   0      0  0.0256
# 333  2023-02-07  14:59:00  0.0253   0      0  0.0256
# 334  2023-02-07  15:00:00  0.0253   0  24151  0.0256
#
# [335 rows x 6 columns]

# %%
option_daily_hist_em_df = ak.option_current_em()

# %%
option_daily_hist_em_df
# Out:
#                  代码               名称       最新价       涨跌额       涨跌幅     成交量  \
# 0      ru2306P11750   橡胶23年06月沽11750  163.0000  162.0000  16200.00     1.0
# 1       v2304c10000  PVC23年04月购10000   50.0000   49.5000   9900.00     1.0
# 2      cu2305P53000   沪铜23年05月沽53000   32.0000   30.0000   1500.00    34.0
# 3         i2306p550    铁矿石23年06月沽550    1.5000    1.4000   1400.00     2.0
# 4        v2305c8000   PVC23年05月购8000    7.0000    6.5000   1300.00   170.0
# ...             ...              ...       ...       ...       ...     ...
# 10827      10004970   300ETF沽2月3840A    0.0012   -0.0028    -70.00  5960.0
# 10828  ru2305P11000   橡胶23年05月沽11000   15.0000  -37.0000    -71.15   212.0
# 10829  ru2305P10500   橡胶23年05月沽10500    5.0000  -13.0000    -72.22    38.0
# 10830   pp2304p8600   聚丙烯23年04月沽8600  201.0000 -537.5000    -72.78     1.0
# 10831  ru2305P10750   橡胶23年05月沽10750    8.0000  -23.0000    -74.19    47.0
#
#              成交额      持仓量   行权价   剩余日      日增       昨结        今开
# ...

# %%
option_daily_hist_em_df[option_daily_hist_em_df['代码'].str.startswith('IF')]
# option_daily_hist_em_df[option_daily_hist_em_df['名称'].str.contains('ETF')]
# Out:
# Empty DataFrame
# Columns: [代码, 名称, 最新价, 涨跌额, 涨跌幅, 成交量, 成交额, 持仓量, 行权价, 剩余日, 日增, 昨结, 今开]
# Index: []

# %%
option_lhb_em_df = ak.option_lhb_em(symbol="510300", indicator="期权持仓情况-认沽持仓量", trade_date="20230206")

# %%
option_lhb_em_df
# Out:
#     交易类型        交易日期    证券代码    标的名称   名次     机构        持仓量       增减  \
# 0  认沽持仓量  2023-02-06  510300  300ETF  1.0   国君期货   135232.0  -5480.0
# 1  认沽持仓量  2023-02-06  510300  300ETF  2.0   中信证券    91783.0  -1347.0
# 2  认沽持仓量  2023-02-06  510300  300ETF  3.0   中信期货    80608.0      0.0
# 3  认沽持仓量  2023-02-06  510300  300ETF  4.0   华泰证券    78548.0   -374.0
# 4  认沽持仓量  2023-02-06  510300  300ETF  5.0   中泰期货    57466.0 -15766.0
# 5  认沽持仓量  2023-02-06  510300  300ETF  NaN  前五名合计   443637.0  -9573.0
# 6  认沽持仓量  2023-02-06  510300  300ETF  NaN   总成交量  1398878.0 -11466.0
#
#        净持仓量   占总交易量比例
# 0   18554.0  0.096672
# 1    7555.0  0.065612
# 2       NaN  0.057623
# 3  -15133.0  0.056151
# 4       NaN  0.041080
# 5   16360.0  0.317138
# 6 -173518.0  1.000000

# %%
stock_zh_index_daily_tx_df = ak.stock_zh_index_daily_tx(symbol="sh000300")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [00:09<00:00,  2.11it/s]

# %%
stock_zh_index_daily_tx_df
# Out:
#             date     open    close     high      low       amount
# 0     2005-01-04   994.77   982.79   994.77   980.66    7412869.0
# 1     2005-01-05   981.58   992.56   997.32   979.88    7119109.0
# 2     2005-01-06   993.33   983.17   993.79   980.33    6288029.0
# 3     2005-01-07   983.04   983.96   995.71   979.81    7298694.0
# 4     2005-01-10   983.76   993.88   993.96   979.79    5791698.0
# ...          ...      ...      ...      ...      ...          ...
# 4390  2023-02-01  4170.13  4195.93  4195.93  4137.77  141008954.0
# 4391  2023-02-02  4207.41  4181.15  4207.41  4170.56  133823736.0
# 4392  2023-02-03  4162.03  4141.63  4162.03  4103.17  117041221.0
# 4393  2023-02-06  4103.83  4086.88  4105.94  4065.22  110192717.0
# 4394  2023-02-07  4098.31  4094.23  4107.34  4077.96   91360072.0
#
# [4395 rows x 6 columns]
