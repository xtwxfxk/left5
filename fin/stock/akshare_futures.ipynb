# %% [markdown]
# # https://www.akshare.xyz/data/futures/futures.html

# %%
import akshare as ak

# %%
futures_comm_info_df = ak.futures_comm_info(symbol="所有")
futures_comm_info_df
# Out:
#          交易所名称       合约名称    合约代码         现价       涨停板       跌停板  保证金-买开  \
# 0      上海期货交易所     沪银2212  ag2212  5370.0000  5907.000  4833.000    20.0
# 1      上海期货交易所     沪银2301  ag2301  5335.0000  5868.000  4801.000    12.0
# 2      上海期货交易所     沪银2302  ag2302  5351.0000  5886.000  4815.000    12.0
# 3      上海期货交易所     沪银2303  ag2303  5351.0000  5886.000  4815.000    12.0
# 4      上海期货交易所     沪银2304  ag2304  5352.0000  5887.000  4816.000    12.0
# ..         ...        ...     ...        ...       ...       ...     ...
# 604  中国金融期货交易所  5年期国债2306  TF2306   100.3549   101.555    99.155     1.2
# 605  中国金融期货交易所  5年期国债2309  TF2309    99.9900   101.185    98.795     1.2
# 606  中国金融期货交易所  2年期国债2303  TS2303   100.7500   101.250   100.250     0.5
# 607  中国金融期货交易所  2年期国债2306  TS2306   100.5300   101.030   100.030     0.5
# 608  中国金融期货交易所  2年期国债2309  TS2309   100.2899   100.790    99.790     0.5
#
#      保证金-卖开     保证金-每手 手续费标准-开仓-万分之  ... 手续费标准-平昨-万分之     手续费标准-平昨-元  \
# ...

# %%
futures_comm_info_df[futures_comm_info_df['合约代码']  == 'rb2305']
# Out:
#        交易所名称     合约名称    合约代码      现价     涨停板     跌停板  保证金-买开  保证金-卖开  保证金-每手  \
# 113  上海期货交易所  螺纹钢2305  rb2305  4031.0  4474.0  3587.0    13.0    13.0  5240.3
#
#     手续费标准-开仓-万分之  ... 手续费标准-平昨-万分之 手续费标准-平昨-元 手续费标准-平今-万分之 手续费标准-平今-元 每跳毛利  \
# 113       0.0001  ...       0.0001  1/万分之(4元)       0.0001  1/万分之(4元)   10
#
#      手续费  每跳净利    备注                  手续费更新时间                   价格更新时间
# 113  8.1   1.9  主力合约  2022-12-15 22:31:05.222  2022-12-16 10:21:51.085
#
# [1 rows x 21 columns]

# %%
futures_zh_minute_sina_df = ak.futures_zh_minute_sina(symbol="rb2305", period="1")

# %%
futures_zh_minute_sina_df
# Out:
#                  datetime    open    high     low   close  volume     hold
# 0     2022-12-13 10:43:00  3929.0  3931.0  3928.0  3929.0    1284  1854107
# 1     2022-12-13 10:44:00  3929.0  3930.0  3927.0  3930.0    1541  1853905
# 2     2022-12-13 10:45:00  3930.0  3931.0  3929.0  3930.0     877  1853943
# 3     2022-12-13 10:46:00  3931.0  3932.0  3927.0  3927.0    1774  1853678
# 4     2022-12-13 10:47:00  3927.0  3928.0  3925.0  3926.0    1237  1853635
# ...                   ...     ...     ...     ...     ...     ...      ...
# 1018  2022-12-16 10:11:00  4067.0  4073.0  4067.0  4071.0    4366  1933473
# 1019  2022-12-16 10:12:00  4071.0  4075.0  4070.0  4075.0    3682  1932391
# 1020  2022-12-16 10:13:00  4074.0  4076.0  4073.0  4075.0    5730  1932277
# 1021  2022-12-16 10:14:00  4074.0  4075.0  4071.0  4072.0    2712  1932136
# 1022  2022-12-16 10:15:00  4071.0  4072.0  4067.0  4067.0    2577  1931973
#
# [1023 rows x 7 columns]
