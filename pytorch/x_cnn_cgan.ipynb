# %%
import os
from tqdm import tnrange, tqdm_notebook, tqdm
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torchvision.utils import save_image, make_grid
from torch.autograd import Variable
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorboardX import SummaryWriter

# %%
# os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = (12, 8)

# %matplotlib inline

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device_ids = [0]

# %%
batch_size = 128
num_epochs = 100

z_dimension = 100
num_feature = (32, 4, 4) # 64 * 64

img_shape = (1, 32, 32)

# %%
img_transform = transforms.Compose([
    transforms.Resize(32),
    transforms.ToTensor(),
    transforms.Normalize((.5, .5, .5), (.5, .5, .5))
])

dataset = datasets.MNIST('/home/left5/datas/mnist', transform=img_transform) #, download=True)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.label_embedding = nn.Embedding(10, np.prod(img_shape))
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(2, 16, 3, padding=1, stride=2),
            nn.LeakyReLU(.2, True),
#             nn.AvgPool2d(2, 2), 
        ) # b 16 16 16
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(16, 32, 3, padding=1, stride=2),
            nn.LeakyReLU(.2, True),
#             nn.AvgPool2d(2, 2), 
        ) # b 32 8 8
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(32, 64, 3, padding=1, stride=2),
            nn.LeakyReLU(.2, True),
#             nn.AvgPool2d(2, 2), 
        ) # b 64 4 4
        
        self.conv4 = nn.Sequential(
            nn.Conv2d(64, 128, 3, padding=1),
            nn.LeakyReLU(.2, True),
#             nn.AvgPool2d(2, 2), 
        ) # b 128 4 4
        
        self.fc = nn.Sequential(
            nn.Linear(128 * 4 * 4, 1024),
            nn.LeakyReLU(.2, True),
            nn.Linear(1024, 1),
            nn.Sigmoid(),
        ) # b 1
        
        self.label = nn.Sequential(
            nn.Linear(128 * 4 * 4, 10),
            nn.Sigmoid()
        )

    def forward(self, imgs, labels): # b 1 32 32
        
        _imgs = torch.cat((imgs, self.label_embedding(labels).reshape(imgs.size(0), *img_shape)), 1)

        outs = self.conv1(_imgs)
        outs = self.conv2(outs)
        outs = self.conv3(outs)
        outs = self.conv4(outs)
        outs = outs.view(imgs.size(0), -1)
        img = self.fc(outs)
        lab = self.label(outs)
        
        return img, lab # b 1 1 1, b 10

# %%
class Generator(nn.Module):
    def __init__(self, inp_dim, num_feature):
        super(Generator, self).__init__()

        self.label_emb = nn.Embedding(10, 10)
        
        self.fc = nn.Sequential(
            nn.Linear(inp_dim, np.prod(num_feature)),
#             nn.Sigmoid(),
        ) # b *num_feature  b 32 4 4
        
        self.upsample1 = nn.Sequential(
#             nn.BatchNorm2d(128),
            nn.ConvTranspose2d(32, 16, 4, 2, 1),
#             nn.functional.interpolate(scale_factor=2),
#             nn.Upsample(scale_factor=2),
#             nn.Conv2d(32, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(.2, True),
#             nn.ReLU(True),
        ) # b 16 8 8
        
        self.upsample2 = nn.Sequential(
#             nn.functional.interpolate(scale_factor=2),
            nn.ConvTranspose2d(16, 8, 4, 2, 1),
#             nn.Upsample(scale_factor=2),
#             nn.Conv2d(16, 8, 3, padding=1),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(.2, True),
#             nn.ReLU(True),
        ) # b 8 16 16
        
        self.upsample3 = nn.Sequential(
            nn.ConvTranspose2d(8, 4, 4, 2, 1),
#             nn.functional.interpolate(scale_factor=2),
#             nn.Upsample(scale_factor=2),
#             nn.Conv2d(8, 4, 3, padding=1, stride=1),
            nn.BatchNorm2d(4),
            nn.LeakyReLU(.2, True),
#             nn.ReLU(True),
        ) # b 4 32 32
        
        self.conv = nn.Sequential(
#             nn.functional.interpolate(scale_factor=2),
            nn.Conv2d(4, 1, 3, padding=1, stride=1),
            nn.Tanh(),
        ) # b 1 32 32

    def forward(self, noise, labels):
        
#         gen_input = torch.cat((labels.reshape(noise.size(0), -1), noise), -1)
        gen_input = torch.cat((self.label_emb(labels), noise), -1)
        
        outs = self.fc(gen_input)
        outs = outs.view(noise.size(0), *num_feature)
        outs = self.upsample1(outs)
        outs = self.upsample2(outs)
        outs = self.upsample3(outs)
        outs = self.conv(outs)
        
        return outs

# %%
D = Discriminator().to(device)
G = Generator(z_dimension + 10, num_feature).to(device)

D = nn.DataParallel(D, device_ids=device_ids).to(device)
G = nn.DataParallel(G, device_ids=device_ids).to(device)

adversarial_loss = nn.MSELoss()
auxiliary_loss = torch.nn.CrossEntropyLoss()

D_optimezer = optim.Adam(D.parameters(), lr=2e-4, betas=(0, 0.9))
G_optimezer = optim.Adam(G.parameters(), lr=2e-4, betas=(0, 0.9))

# %%
condition = torch.from_numpy(np.arange(10)).cuda()

# %%
writer = SummaryWriter('./log/cnn_cgan')

# %%
img_path = "save_images/cnn_cgan"
if not os.path.exists(img_path): os.makedirs(img_path)

# %%
total_count = len(dataloader)
for epoch in tqdm_notebook(range(num_epochs)):
    _step = epoch * total_count
    
    d_loss_total = .0
    g_loss_total = .0
    for i, (imgs, labels) in enumerate(dataloader):
        
        real_imgs = imgs.cuda()
        real_labels = labels.cuda()
        
        real = torch.ones(imgs.size(0), 1).cuda()
        fake = torch.zeros(imgs.size(0), 1).cuda()
        
        z = torch.randn(imgs.size(0), z_dimension).cuda()
        fake_labels = torch.from_numpy(np.random.randint(0, 10, imgs.size(0))).cuda()
        
        ########## G ##########
        fake_imgs = G(z, fake_labels)
        fake_out, fake_out_labels = D(fake_imgs, fake_labels)
        g_loss = adversarial_loss(fake_out, real)
        
        G_optimezer.zero_grad()
        g_loss.backward()
        G_optimezer.step()
        #######################
        
        ########## D ##########
        real_out, real_out_label = D(real_imgs, real_labels)
        d_loss_real = adversarial_loss(real_out, real_labels.float())
#         d_loss_real_label = auxiliary_loss(real_out_label, real_labels)
        real_scores = real_out
        
        fake_out, fake_out_label = D(fake_imgs.detach(), fake_labels)
        d_loss_fake = adversarial_loss(fake_out, fake)
        fake_scores = fake_out
        
        d_loss = (d_loss_real + d_loss_fake) / 2 # + d_loss_real_label
        D_optimezer.zero_grad()
        d_loss.backward()
        D_optimezer.step()
        #######################
        
        d_loss_total += d_loss.item() * imgs.size(0)
        g_loss_total += g_loss.item() * imgs.size(0)
        
        step = _step + i + 1
        
        if (i + 1) % 100 == 0:
            writer.add_scalar('Discriminator Real Loss', d_loss_real.item(), step)
            writer.add_scalar('Discriminator Fake Loss', d_loss_fake.item(), step)
            writer.add_scalar('Discriminator Loss', d_loss.item(), step)
            writer.add_scalar('Generator Loss', g_loss.item(), step)
        
        if (i + 1) % 300 == 0:
            tqdm.write('Epoch [{}/{}], Step: {:6d}, d_loss: {:.6f}, g_loss: {:.6f}, real_scores: {:.6f}' \
', fake_scores: {:.6f}'.format(epoch+1, num_epochs, (i+1) * batch_size, d_loss, g_loss, real_scores.mean(), fake_scores.mean()))
    
    setp = (epoch + 1) * total_count
    _d_loss_total = d_loss_total / (total_count * (epoch + 1))
    _g_loss_total = g_loss_total / (total_count * (epoch + 1))
    
    writer.add_scalar('Discriminator Total Loss', _d_loss_total, step)
    writer.add_scalar('Generator Total Loss', _g_loss_total, step)
    
    tqdm.write("Finish Epoch [{}/{}], D Loss: {:.6f}, G Loss: {:.6f}".format(epoch+1, 
                                                                             num_epochs, 
                                                                             _d_loss_total,
                                                                             _g_loss_total, ))
    
    if epoch == 0:
        real_images = real_imgs.view(-1, 1, 32, 32).cpu().data
        save_image(real_images, os.path.join(img_path, 'real_images.png'))
        
    noise = torch.randn(10, z_dimension).cuda()
    condition_images = G(noise, condition)
    
    writer.add_image('Generator Image', make_grid(fake_imgs.view(-1, 1, 32, 32).cpu().data, normalize=True, scale_each=True), step)
    writer.add_image('Condition Generator Image', make_grid(condition_images.view(-1, 1, 32, 32).cpu().data, normalize=True, scale_each=True), step)
    
    fake_images = fake_imgs.view(-1, 1, 32, 32).cpu().data
    save_image(fake_images, os.path.join(img_path, 'fake_images-{}.png'.format(epoch+1)))
    save_image(condition_images, os.path.join(img_path, 'condition_images-{}.png'.format(epoch+1)))
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Epoch [1/100], Step:  38400, d_loss: 11.104020, g_loss: 0.823807, real_scores: 1.000000, fake_scores: 0.164773
# Finish Epoch [1/100], D Loss: 1310.855971, G Loss: 104.757788
# Epoch [2/100], Step:  38400, d_loss: 11.560197, g_loss: 0.410546, real_scores: 0.999919, fake_scores: 0.565560
# Finish Epoch [2/100], D Loss: 667.422972, G Loss: 26.743573
# Epoch [3/100], Step:  38400, d_loss: 9.705365, g_loss: 0.001828, real_scores: 0.999317, fake_scores: 0.979665
# Finish Epoch [3/100], D Loss: 453.492502, G Loss: 1.841030
# Epoch [4/100], Step:  38400, d_loss: 8.839767, g_loss: 0.000000, real_scores: 0.999977, fake_scores: 0.999855
# Finish Epoch [4/100], D Loss: 340.284528, G Loss: 0.747447
# Epoch [5/100], Step:  38400, d_loss: 11.441399, g_loss: 0.000000, real_scores: 0.999997, fake_scores: 0.999981
# Finish Epoch [5/100], D Loss: 272.103697, G Loss: 0.476932
# Epoch [6/100], Step:  38400, d_loss: 10.237126, g_loss: 0.001724, real_scores: 0.999057, fake_scores: 0.990781
# Finish Epoch [6/100], D Loss: 226.811369, G Loss: 0.163656
# Epoch [7/100], Step:  38400, d_loss: 11.351560, g_loss: 0.000000, real_scores: 0.999999, fake_scores: 0.999993
# Finish Epoch [7/100], D Loss: 194.436827, G Loss: 0.073398
# Epoch [8/100], Step:  38400, d_loss: 10.059690, g_loss: 0.030385, real_scores: 0.998766, fake_scores: 0.931122
# Finish Epoch [8/100], D Loss: 169.717850, G Loss: 0.936317
# Epoch [9/100], Step:  38400, d_loss: 11.249660, g_loss: 0.001929, real_scores: 0.999070, fake_scores: 0.983741
# Finish Epoch [9/100], D Loss: 150.981103, G Loss: 0.605853
# Epoch [10/100], Step:  38400, d_loss: 10.035342, g_loss: 0.050839, real_scores: 0.987261, fake_scores: 0.895857
# Finish Epoch [10/100], D Loss: 135.981918, G Loss: 0.417358
# Epoch [11/100], Step:  38400, d_loss: 11.785381, g_loss: 0.000002, real_scores: 0.999826, fake_scores: 0.999563
# Finish Epoch [11/100], D Loss: 123.675715, G Loss: 0.314352
# Epoch [12/100], Step:  38400, d_loss: 10.005573, g_loss: 0.040974, real_scores: 0.995656, fake_scores: 0.907745
# Finish Epoch [12/100], D Loss: 113.078116, G Loss: 0.827281
# Epoch [13/100], Step:  38400, d_loss: 11.933116, g_loss: 0.074004, real_scores: 0.984863, fake_scores: 0.859857
# Finish Epoch [13/100], D Loss: 104.337347, G Loss: 0.896781
# Epoch [14/100], Step:  38400, d_loss: 10.226232, g_loss: 0.030489, real_scores: 0.990047, fake_scores: 0.930606
# Finish Epoch [14/100], D Loss: 96.872236, G Loss: 0.849661
# Epoch [15/100], Step:  38400, d_loss: 11.315352, g_loss: 0.005568, real_scores: 0.999321, fake_scores: 0.978024
# Finish Epoch [15/100], D Loss: 90.381713, G Loss: 0.848946
# Epoch [16/100], Step:  38400, d_loss: 12.248980, g_loss: 0.261978, real_scores: 0.938599, fake_scores: 0.615972
# Finish Epoch [16/100], D Loss: 84.824310, G Loss: 0.609593
# Epoch [17/100], Step:  38400, d_loss: 11.687048, g_loss: 0.007372, real_scores: 0.999008, fake_scores: 0.980445
# Finish Epoch [17/100], D Loss: 79.868333, G Loss: 0.525208
# Epoch [18/100], Step:  38400, d_loss: 10.103844, g_loss: 0.020959, real_scores: 0.990327, fake_scores: 0.946666
# Finish Epoch [18/100], D Loss: 75.376974, G Loss: 0.557730
# Epoch [19/100], Step:  38400, d_loss: 9.534854, g_loss: 0.126599, real_scores: 0.975118, fake_scores: 0.801745
# Finish Epoch [19/100], D Loss: 71.456905, G Loss: 0.449978
# Epoch [20/100], Step:  38400, d_loss: 12.530476, g_loss: 0.008234, real_scores: 0.999740, fake_scores: 0.978444
# Finish Epoch [20/100], D Loss: 67.926863, G Loss: 0.358185
# Epoch [21/100], Step:  38400, d_loss: 11.609143, g_loss: 0.002410, real_scores: 0.999104, fake_scores: 0.987433
# Finish Epoch [21/100], D Loss: 64.711512, G Loss: 0.275352
# Epoch [22/100], Step:  38400, d_loss: 10.702400, g_loss: 0.004890, real_scores: 0.999899, fake_scores: 0.988659
# Finish Epoch [22/100], D Loss: 61.783651, G Loss: 0.249177
# Epoch [23/100], Step:  38400, d_loss: 9.800491, g_loss: 0.229796, real_scores: 0.924593, fake_scores: 0.627192
# Finish Epoch [23/100], D Loss: 59.098462, G Loss: 0.201847
# Epoch [24/100], Step:  38400, d_loss: 10.447694, g_loss: 0.006170, real_scores: 0.998005, fake_scores: 0.972580
# Finish Epoch [24/100], D Loss: 56.637908, G Loss: 0.196437
# Epoch [25/100], Step:  38400, d_loss: 8.532615, g_loss: 0.006004, real_scores: 0.995175, fake_scores: 0.971908
# Finish Epoch [25/100], D Loss: 54.385505, G Loss: 0.159433
# Epoch [26/100], Step:  38400, d_loss: 12.527381, g_loss: 0.107683, real_scores: 0.952002, fake_scores: 0.809946
# Finish Epoch [26/100], D Loss: 52.278150, G Loss: 0.178225
# Epoch [27/100], Step:  38400, d_loss: 11.371462, g_loss: 0.002685, real_scores: 0.999722, fake_scores: 0.990212
# Finish Epoch [27/100], D Loss: 50.374758, G Loss: 0.122701
# Epoch [28/100], Step:  38400, d_loss: 11.853196, g_loss: 0.027590, real_scores: 0.982884, fake_scores: 0.925146
# Finish Epoch [28/100], D Loss: 48.567716, G Loss: 0.110677
# Epoch [29/100], Step:  38400, d_loss: 11.437446, g_loss: 0.000000, real_scores: 1.000000, fake_scores: 0.999944
# Finish Epoch [29/100], D Loss: 46.939199, G Loss: 0.029980
# Epoch [30/100], Step:  38400, d_loss: 10.417520, g_loss: 0.000057, real_scores: 0.998755, fake_scores: 0.999043
# Finish Epoch [30/100], D Loss: 45.364405, G Loss: 0.031300
# Epoch [31/100], Step:  38400, d_loss: 10.632254, g_loss: 0.024191, real_scores: 0.989752, fake_scores: 0.936048
# Finish Epoch [31/100], D Loss: 43.866454, G Loss: 0.106526
# Epoch [32/100], Step:  38400, d_loss: 10.347212, g_loss: 0.000011, real_scores: 0.999972, fake_scores: 0.999454
# Finish Epoch [32/100], D Loss: 42.530665, G Loss: 0.029725
# Epoch [33/100], Step:  38400, d_loss: 10.765648, g_loss: 0.000000, real_scores: 0.999974, fake_scores: 0.999935
# Finish Epoch [33/100], D Loss: 41.239944, G Loss: 0.016683
# Epoch [34/100], Step:  38400, d_loss: 10.548599, g_loss: 0.068428, real_scores: 0.970963, fake_scores: 0.852994
# Finish Epoch [34/100], D Loss: 40.018813, G Loss: 0.046752
# Epoch [35/100], Step:  38400, d_loss: 10.777340, g_loss: 0.000000, real_scores: 1.000000, fake_scores: 0.999996
# Finish Epoch [35/100], D Loss: 38.885364, G Loss: 0.015652
# Epoch [36/100], Step:  38400, d_loss: 8.199192, g_loss: 0.000000, real_scores: 1.000000, fake_scores: 0.999972
# Finish Epoch [36/100], D Loss: 37.798943, G Loss: 0.032651
# Epoch [37/100], Step:  38400, d_loss: 11.581909, g_loss: 0.000002, real_scores: 1.000000, fake_scores: 0.999877
# Finish Epoch [37/100], D Loss: 36.788091, G Loss: 0.003837
# Epoch [38/100], Step:  38400, d_loss: 9.149022, g_loss: 0.030204, real_scores: 0.992935, fake_scores: 0.939214
# Finish Epoch [38/100], D Loss: 35.818613, G Loss: 0.020936
# Epoch [39/100], Step:  38400, d_loss: 9.838836, g_loss: 0.129106, real_scores: 0.942543, fake_scores: 0.756228
# Finish Epoch [39/100], D Loss: 34.890675, G Loss: 0.034341
# Epoch [40/100], Step:  38400, d_loss: 10.474990, g_loss: 0.021393, real_scores: 0.997665, fake_scores: 0.948408
# Finish Epoch [40/100], D Loss: 34.004911, G Loss: 0.053875
# Epoch [41/100], Step:  38400, d_loss: 10.408655, g_loss: 0.001976, real_scores: 0.999342, fake_scores: 0.995262
# Finish Epoch [41/100], D Loss: 33.173442, G Loss: 0.062850
# Epoch [42/100], Step:  38400, d_loss: 10.222684, g_loss: 0.000000, real_scores: 0.999985, fake_scores: 0.999976
# Finish Epoch [42/100], D Loss: 32.395389, G Loss: 0.036001
# Epoch [43/100], Step:  38400, d_loss: 10.597575, g_loss: 0.000001, real_scores: 0.999999, fake_scores: 0.999914
# Finish Epoch [43/100], D Loss: 31.647788, G Loss: 0.027291
# Epoch [44/100], Step:  38400, d_loss: 10.178392, g_loss: 0.067148, real_scores: 0.966194, fake_scores: 0.895842
# Finish Epoch [44/100], D Loss: 30.933607, G Loss: 0.018204
# Epoch [45/100], Step:  38400, d_loss: 11.312503, g_loss: 0.013647, real_scores: 0.984410, fake_scores: 0.955919
# Finish Epoch [45/100], D Loss: 30.235180, G Loss: 0.038297
# Epoch [46/100], Step:  38400, d_loss: 11.406365, g_loss: 0.021119, real_scores: 0.992134, fake_scores: 0.932595
# Finish Epoch [46/100], D Loss: 29.571023, G Loss: 0.051484
# Epoch [47/100], Step:  38400, d_loss: 10.397097, g_loss: 0.012431, real_scores: 0.997131, fake_scores: 0.955052
# Finish Epoch [47/100], D Loss: 28.944467, G Loss: 0.044630
# Epoch [48/100], Step:  38400, d_loss: 9.925650, g_loss: 0.000003, real_scores: 0.999963, fake_scores: 0.999745
# Finish Epoch [48/100], D Loss: 28.339093, G Loss: 0.051803
# Epoch [49/100], Step:  38400, d_loss: 9.592060, g_loss: 0.011423, real_scores: 0.996219, fake_scores: 0.968496
# Finish Epoch [49/100], D Loss: 27.759330, G Loss: 0.054612
# Epoch [50/100], Step:  38400, d_loss: 10.973621, g_loss: 0.025197, real_scores: 0.999059, fake_scores: 0.957643
# Finish Epoch [50/100], D Loss: 27.206909, G Loss: 0.042388
# Epoch [51/100], Step:  38400, d_loss: 10.351202, g_loss: 0.000010, real_scores: 0.999998, fake_scores: 0.999629
# Finish Epoch [51/100], D Loss: 26.678216, G Loss: 0.034300
# Epoch [52/100], Step:  38400, d_loss: 10.454487, g_loss: 0.008401, real_scores: 0.993631, fake_scores: 0.981843
# Finish Epoch [52/100], D Loss: 26.169341, G Loss: 0.024814
# Epoch [53/100], Step:  38400, d_loss: 10.128338, g_loss: 0.051709, real_scores: 0.983504, fake_scores: 0.874037
# Finish Epoch [53/100], D Loss: 25.666266, G Loss: 0.038089
# Epoch [54/100], Step:  38400, d_loss: 11.449113, g_loss: 0.000000, real_scores: 0.999999, fake_scores: 0.999891
# Finish Epoch [54/100], D Loss: 25.199213, G Loss: 0.024818
# Epoch [55/100], Step:  38400, d_loss: 11.034904, g_loss: 0.003767, real_scores: 0.993500, fake_scores: 0.989809
# Finish Epoch [55/100], D Loss: 24.738486, G Loss: 0.028850
# Epoch [56/100], Step:  38400, d_loss: 12.086194, g_loss: 0.000373, real_scores: 0.999891, fake_scores: 0.995730
# Finish Epoch [56/100], D Loss: 24.298701, G Loss: 0.025853
# Epoch [57/100], Step:  38400, d_loss: 10.224875, g_loss: 0.012445, real_scores: 0.999427, fake_scores: 0.966688
# Finish Epoch [57/100], D Loss: 23.876319, G Loss: 0.027643
# Epoch [58/100], Step:  38400, d_loss: 10.535503, g_loss: 0.005884, real_scores: 0.992663, fake_scores: 0.987323
# Finish Epoch [58/100], D Loss: 23.457801, G Loss: 0.034927
# Epoch [59/100], Step:  38400, d_loss: 8.645731, g_loss: 0.202341, real_scores: 0.881807, fake_scores: 0.671143
# Finish Epoch [59/100], D Loss: 23.057692, G Loss: 0.037890
# Epoch [60/100], Step:  38400, d_loss: 10.001347, g_loss: 0.020670, real_scores: 0.995260, fake_scores: 0.943600
# Finish Epoch [60/100], D Loss: 22.675205, G Loss: 0.033816
# Epoch [61/100], Step:  38400, d_loss: 10.418288, g_loss: 0.005404, real_scores: 0.999807, fake_scores: 0.989112
# Finish Epoch [61/100], D Loss: 22.299364, G Loss: 0.041418
# Epoch [62/100], Step:  38400, d_loss: 10.175529, g_loss: 0.036996, real_scores: 0.988291, fake_scores: 0.919857
# Finish Epoch [62/100], D Loss: 21.934664, G Loss: 0.044556
# Epoch [63/100], Step:  38400, d_loss: 11.633961, g_loss: 0.010864, real_scores: 0.982485, fake_scores: 0.972414
# Finish Epoch [63/100], D Loss: 21.594163, G Loss: 0.035570
# Epoch [64/100], Step:  38400, d_loss: 11.429248, g_loss: 0.013691, real_scores: 0.999581, fake_scores: 0.963853
# Finish Epoch [64/100], D Loss: 21.252160, G Loss: 0.043590
# Epoch [65/100], Step:  38400, d_loss: 10.058013, g_loss: 0.024374, real_scores: 0.992448, fake_scores: 0.941778
# Finish Epoch [65/100], D Loss: 20.925334, G Loss: 0.042943
# Epoch [66/100], Step:  38400, d_loss: 10.042218, g_loss: 0.007185, real_scores: 0.992004, fake_scores: 0.971609
# Finish Epoch [66/100], D Loss: 20.604492, G Loss: 0.046931
# Epoch [67/100], Step:  38400, d_loss: 11.533876, g_loss: 0.006116, real_scores: 0.996884, fake_scores: 0.983577
# Finish Epoch [67/100], D Loss: 20.299819, G Loss: 0.047203
# Epoch [68/100], Step:  38400, d_loss: 10.275325, g_loss: 0.005556, real_scores: 0.999644, fake_scores: 0.978433
# Finish Epoch [68/100], D Loss: 20.004030, G Loss: 0.039561
# Epoch [69/100], Step:  38400, d_loss: 10.806430, g_loss: 0.000261, real_scores: 0.999985, fake_scores: 0.997654
# Finish Epoch [69/100], D Loss: 19.706990, G Loss: 0.048560
# Epoch [70/100], Step:  38400, d_loss: 10.154055, g_loss: 0.033553, real_scores: 0.992414, fake_scores: 0.928869
# Finish Epoch [70/100], D Loss: 19.424814, G Loss: 0.053633
# Epoch [71/100], Step:  38400, d_loss: 12.857350, g_loss: 0.020024, real_scores: 0.990646, fake_scores: 0.943974
# Finish Epoch [71/100], D Loss: 19.149888, G Loss: 0.056169
# Epoch [72/100], Step:  38400, d_loss: 10.753364, g_loss: 0.033067, real_scores: 0.996676, fake_scores: 0.932341
# Finish Epoch [72/100], D Loss: 18.886306, G Loss: 0.057897
# Epoch [73/100], Step:  38400, d_loss: 8.748844, g_loss: 0.000088, real_scores: 0.999998, fake_scores: 0.998795
# Finish Epoch [73/100], D Loss: 18.621881, G Loss: 0.059125
# Epoch [74/100], Step:  38400, d_loss: 11.953195, g_loss: 0.057288, real_scores: 0.984083, fake_scores: 0.891576
# Finish Epoch [74/100], D Loss: 18.368139, G Loss: 0.060440
# Epoch [75/100], Step:  38400, d_loss: 10.189963, g_loss: 0.020009, real_scores: 0.984310, fake_scores: 0.952839
# Finish Epoch [75/100], D Loss: 18.120715, G Loss: 0.063800
# Epoch [76/100], Step:  38400, d_loss: 10.775710, g_loss: 0.061840, real_scores: 0.959406, fake_scores: 0.897707
# Finish Epoch [76/100], D Loss: 17.884575, G Loss: 0.061730
# Epoch [77/100], Step:  38400, d_loss: 10.676929, g_loss: 0.030497, real_scores: 0.994456, fake_scores: 0.926429
# Finish Epoch [77/100], D Loss: 17.650803, G Loss: 0.063154
# Epoch [78/100], Step:  38400, d_loss: 9.406102, g_loss: 0.005558, real_scores: 0.999980, fake_scores: 0.989196
# Finish Epoch [78/100], D Loss: 17.426188, G Loss: 0.059082
# Epoch [79/100], Step:  38400, d_loss: 12.158964, g_loss: 0.000056, real_scores: 0.999998, fake_scores: 0.998774
# Finish Epoch [79/100], D Loss: 17.205666, G Loss: 0.059553
# Epoch [80/100], Step:  38400, d_loss: 10.646066, g_loss: 0.000662, real_scores: 0.999482, fake_scores: 0.995472
# Finish Epoch [80/100], D Loss: 16.986359, G Loss: 0.062889
# Epoch [81/100], Step:  38400, d_loss: 11.651834, g_loss: 0.083649, real_scores: 0.993631, fake_scores: 0.855712
# Finish Epoch [81/100], D Loss: 16.773700, G Loss: 0.073848
# Epoch [82/100], Step:  38400, d_loss: 9.855532, g_loss: 0.002821, real_scores: 0.999949, fake_scores: 0.986777
# Finish Epoch [82/100], D Loss: 16.564896, G Loss: 0.078604
# Epoch [83/100], Step:  38400, d_loss: 10.674237, g_loss: 0.003892, real_scores: 0.999964, fake_scores: 0.988569
# Finish Epoch [83/100], D Loss: 16.371470, G Loss: 0.073253
# Epoch [84/100], Step:  38400, d_loss: 11.756998, g_loss: 0.006433, real_scores: 0.999995, fake_scores: 0.992043
# Finish Epoch [84/100], D Loss: 16.179489, G Loss: 0.062106
# Epoch [85/100], Step:  38400, d_loss: 9.943890, g_loss: 0.194537, real_scores: 0.975759, fake_scores: 0.707610
# Finish Epoch [85/100], D Loss: 15.966770, G Loss: 0.099019
# Epoch [86/100], Step:  38400, d_loss: 10.978754, g_loss: 0.017308, real_scores: 0.997116, fake_scores: 0.963451
# Finish Epoch [86/100], D Loss: 15.787520, G Loss: 0.092635
# Epoch [87/100], Step:  38400, d_loss: 9.224920, g_loss: 0.219587, real_scores: 0.944822, fake_scores: 0.674855
# Finish Epoch [87/100], D Loss: 15.603434, G Loss: 0.096034
# Epoch [88/100], Step:  38400, d_loss: 9.164972, g_loss: 0.190248, real_scores: 0.964819, fake_scores: 0.701386
# Finish Epoch [88/100], D Loss: 15.422126, G Loss: 0.102907
# Epoch [89/100], Step:  38400, d_loss: 10.831198, g_loss: 0.000834, real_scores: 0.999989, fake_scores: 0.994804
# Finish Epoch [89/100], D Loss: 15.256564, G Loss: 0.088055
# Epoch [90/100], Step:  38400, d_loss: 8.860543, g_loss: 0.180638, real_scores: 0.986370, fake_scores: 0.723808
# Finish Epoch [90/100], D Loss: 15.080655, G Loss: 0.097846
# Epoch [91/100], Step:  38400, d_loss: 10.408124, g_loss: 0.025610, real_scores: 0.998500, fake_scores: 0.940753
# Finish Epoch [91/100], D Loss: 14.911822, G Loss: 0.100635
# Epoch [92/100], Step:  38400, d_loss: 10.282495, g_loss: 0.006716, real_scores: 0.999994, fake_scores: 0.986150
# Finish Epoch [92/100], D Loss: 14.746797, G Loss: 0.109343
# Epoch [93/100], Step:  38400, d_loss: 10.517910, g_loss: 0.209909, real_scores: 0.964072, fake_scores: 0.668880
# Finish Epoch [93/100], D Loss: 14.586137, G Loss: 0.114151
# Epoch [94/100], Step:  38400, d_loss: 11.881413, g_loss: 0.345024, real_scores: 0.853068, fake_scores: 0.528256
# Finish Epoch [94/100], D Loss: 14.434423, G Loss: 0.104303
# Epoch [95/100], Step:  38400, d_loss: 10.412936, g_loss: 0.043645, real_scores: 0.992618, fake_scores: 0.910546
# Finish Epoch [95/100], D Loss: 14.280571, G Loss: 0.106138
# Epoch [96/100], Step:  38400, d_loss: 9.551132, g_loss: 0.132230, real_scores: 0.990891, fake_scores: 0.787518
# Finish Epoch [96/100], D Loss: 14.119192, G Loss: 0.130496
# Epoch [97/100], Step:  38400, d_loss: 10.467696, g_loss: 0.196950, real_scores: 0.985354, fake_scores: 0.703936
# Finish Epoch [97/100], D Loss: 13.975172, G Loss: 0.131064
# Epoch [98/100], Step:  38400, d_loss: 9.274160, g_loss: 0.115690, real_scores: 0.985025, fake_scores: 0.798701
# Finish Epoch [98/100], D Loss: 13.829878, G Loss: 0.129778
# Epoch [99/100], Step:  38400, d_loss: 11.332123, g_loss: 0.175590, real_scores: 0.981686, fake_scores: 0.744832
# Finish Epoch [99/100], D Loss: 13.673663, G Loss: 0.157202
# Epoch [100/100], Step:  38400, d_loss: 12.560430, g_loss: 0.121933, real_scores: 0.985741, fake_scores: 0.801799
# Finish Epoch [100/100], D Loss: 13.543769, G Loss: 0.152453

# %%
writer.close()

# %%
torch.save(D.state_dict(), './ser/cgan_discriminator.pt')
torch.save(G.state_dict(), './ser/cgan_generator.pt')

# %%
words = np.array([4,5,1,3,0,8,8])
l = torch.from_numpy(words).cuda()
z = torch.randn(words.size, z_dimension).to(device)
images = G(z, l)
# save_image(images, 'xx.png')
plt.imshow(Image.fromarray(make_grid(images).mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()))
plt.show()
